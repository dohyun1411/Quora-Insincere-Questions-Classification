# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyun1411/Quora-Insincere-Questions-Classification/blob/preprocessing1/embedding_with_tweet_tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gc
import random

import numpy as np
import pandas as pd
from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

# %%
def seed_torch(seed=31):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_torch()
device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# device(type='cuda')

# %%
import os

# input_path = '/kaggle/input/quora-insincere-questions-classification'
input_path = '/content/drive/MyDrive/ColabNotebooks/QIQC/data'
train_path = os.path.join(input_path, 'train.csv')
test_path = os.path.join(input_path, 'test.csv')
embeddings_path = os.path.join(input_path, 'embeddings.zip')

# %%
if os.path.exists(train_path): train_df = pd.read_csv(train_path)
else: train_df = pd.read_csv(train_path + '.zip')

if os.path.exists(test_path): test_df = pd.read_csv(train_path)
else: test_df = pd.read_csv(test_path + '.zip')

print('train shape:', train_df.shape)
print('test shape:', test_df.shape)
# Out:
# train shape: (1306122, 3)
# test shape: (1306122, 3)

# %%
from sklearn.model_selection import train_test_split

# split to train and val
train_df, val_df = train_test_split(train_df, test_size=0.1)

# some config values 
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use

# fill up the missing values
train_X = train_df["question_text"].fillna("_na_").values
val_X = val_df["question_text"].fillna("_na_").values
test_X = test_df["question_text"].fillna("_na_").values

# Get the target values
train_y = train_df['target'].values
val_y = val_df['target'].values

# %%
import nltk
from nltk.tokenize import TweetTokenizer

tweet_tknzr = TweetTokenizer(preserve_case=True, reduce_len=True, strip_handles=True)

# %%
import zipfile
from gensim.models import KeyedVectors

glove = 'glove.840B.300d/glove.840B.300d.txt'
wiki = 'wiki-news-300d-1M/wiki-news-300d-1M.vec'
google = 'GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'
para = 'paragram_300_sl999/paragram_300_sl999.txt'


def _load_embedding(embedding_name):

    def get_coefs(word, *arr): return word, np.asarray(arr, dtype='float32')

    with zipfile.ZipFile(embeddings_path) as embeddings_zip:
        print("Found embeddings as a zip file")

        if embedding_name == google:
            return KeyedVectors.load_word2vec_format(embeddings_zip.open(google), binary=True)

        else:
            embedding = []
            for o in embeddings_zip.open(embedding_name):
                try:
                    if len(o.decode('utf-8')) > 100:
                        embedding.append(get_coefs(*o.decode('utf-8').split(" ")))
                except:
                    pass
        
        return dict(embedding)
  

def load_embeddings(emb_idx=1234):
    """
    


    """

# %%
# %%time
glove_embedding = load_embedding(glove) # 3min 21s in Colab
# Out:
# Found embeddings as a zip file
# CPU times: user 4min 10s, sys: 6.33 s, total: 4min 16s
# Wall time: 4min 17s

# %%
from collections import defaultdict
import operator

def build_vocab(sentences, verbose=1):
    """
    :param sentences: list of list of words
    :return: dictionary of words and their count
    """

    vocab = defaultdict(int)
    for sentence in tqdm(sentences, disable=(not verbose)):
        for word in sentence:
            vocab[word] += 1
    return dict(sorted(vocab.items(), key=operator.itemgetter(1), reverse=True))

# %%
build_vocab([['hi', 'ih', 'hi']])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# [('hi', 2), ('ih', 1)]

# %%
train_X
# Out:
# array(['What are some supernatural related things in the DCEU and MCU?',
#        'What are the best master degrees in computational finance?',
#        'Is changing the First Amendment something the Trump administration considers to be a viable strategy to combat "fake news"?',
#        ...,
#        'What might be some of the reasons for my feet to turn red while running?',
#        'Is 22 too old to start learning computer engineering?',
#        'Where can you find a template for a personal stock trading journal?'],
#       dtype=object)

# %%
sentences = train_df["question_text"].fillna("_na_").progress_apply(tweet_tknzr.tokenize).values
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1175509.0), HTML(value='')))

# %%
vocab = build_vocab(sentences)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1175509.0), HTML(value='')))

# %%
vocab
# Out:
# defaultdict(int,
#             {'What': 378162,
#              'are': 192523,
#              'some': 48609,
#              'supernatural': 161,
#              'related': 2745,
#              'things': 9713,
#              'in': 330063,
#              'the': 589611,
#              'DCEU': 72,
#              'and': 228687,
#              'MCU': 401,
#              '?': 1242841,
#              'best': 56220,
#              'master': 940,
#              'degrees': 675,
#              'computational': 122,
#              'finance': 1206,
#              'Is': 98108,
#              'changing': 999,
#              'First': 399,
#              'Amendment': 285,
#              'something': 7126,
#              'Trump': 11213,
#              'administration': 664,
#              'considers': 88,
#              'to': 365411,
#              'be': 82281,
#              'a': 363985,
#              'viable': 250,
#              'strategy': 1559,
#              'combat': 538,
#              '"': 66156,
#              'fake': 2002,
#              'news': 2109,
#              'is': 300654,
#              'lowest': 386,
#              'paying': 1099,
#              'job': 12843,
#              'anywhere': 521,
#              'world': 13160,
#              ',': 208922,
#              'what': 33720,
#              'highest': 1273,
#              'Which': 42619,
#              'areas': 1089,
#              'good': 34351,
#              'for': 181606,
#              'bachelors': 242,
#              'Pune': 1704,
#              'How': 236351,
#              'do': 191581,
#              'I': 281525,
#              'get': 56220,
#              'banks': 865,
#              'Nigeria': 783,
#              'look': 6870,
#              'into': 14419,
#              'an': 60229,
#              'idea': 3430,
#              'have': 76902,
#              'design': 3269,
#              'as': 50225,
#              'value': 3477,
#              'added': 703,
#              'service': 3472,
#              'Why': 130737,
#              'there': 47131,
#              'no': 12708,
#              'gas': 1648,
#              'station': 573,
#              'sells': 157,
#              'leaded': 6,
#              'channel': 1124,
#              'names': 1529,
#              'how': 24159,
#              'family': 5009,
#              'fun': 1526,
#              'can': 112360,
#              'second': 2413,
#              'hand': 1747,
#              'price': 2435,
#              '5': 5976,
#              'month': 3234,
#              'old': 9451,
#              'Fender': 15,
#              'Squier': 5,
#              'Affinity': 10,
#              'Stratocaster': 6,
#              'with': 84837,
#              'Rosewood': 6,
#              'fingerboard': 5,
#              'all': 22798,
#              'single': 3283,
#              'coil': 165,
#              'pickup': 117,
#              'does': 56873,
#              'Chinese': 5589,
#              'Communist': 178,
#              'Party': 665,
#              'want': 16757,
#              'treat': 2461,
#              'citizens': 1262,
#              'of': 299898,
#              'brain': 2456,
#              'damage': 940,
#              'sand': 327,
#              'sculptures': 37,
#              'done': 5469,
#              'If': 31222,
#              'you': 175922,
#              'see': 8636,
#              'middle-aged': 28,
#              'man': 5671,
#              'or': 83290,
#              'woman': 4386,
#              'on': 84123,
#              'Quora': 14060,
#              'whose': 710,
#              'profile': 1504,
#              'picture': 1199,
#              'selfie': 74,
#              'they': 37271,
#              'over': 10126,
#              '1,000': 166,
#              'answers': 2751,
#              'assume': 508,
#              'person': 14558,
#              'loser': 133,
#              'life': 19687,
#              'West': 1387,
#              'learn': 10236,
#              'from': 61382,
#              "China's": 364,
#              'ability': 893,
#              'use': 19499,
#              'coercion': 13,
#              'keep': 6119,
#              'its': 8811,
#              'corporations': 188,
#              'CEOs': 78,
#              'billionaires': 137,
#              'line': 2103,
#              'national': 1479,
#              'interest': 1855,
#              'CPC': 51,
#              'ideals': 88,
#              '.': 104364,
#              'should': 43032,
#              'know': 18086,
#              'before': 9773,
#              'visiting': 777,
#              'Switzerland': 390,
#              'gospel': 59,
#              'Jesus': 1480,
#              'Not': 459,
#              'born': 1826,
#              'again': 3043,
#              'types': 2687,
#              'but': 24047,
#              'that': 95911,
#              "'": 20286,
#              'himself': 1049,
#              'taught': 796,
#              'corruption': 561,
#              'inevitable': 143,
#              'evil': 1051,
#              'Who': 19963,
#              'won': 1135,
#              'mahab': 1,
#              'harassment': 333,
#              'battle': 675,
#              'people': 49533,
#              'sell': 2694,
#              'trademarked': 26,
#              'products': 2388,
#              'Etsy': 58,
#              'Does': 20875,
#              'Ali': 276,
#              'AlShamsi': 40,
#              'respond': 922,
#              'Twitter': 958,
#              'messages': 953,
#              'pros': 1180,
#              'cons': 1200,
#              'joining': 1104,
#              'each': 4915,
#              'branch': 1795,
#              'military': 2944,
#              ':': 6285,
#              'Coast': 123,
#              'Guard': 106,
#              'Navy': 453,
#              'Army': 712,
#              'Air': 601,
#              'Force': 427,
#              'National': 854,
#              'unconventional': 56,
#              'ways': 6410,
#              'raise': 819,
#              'my': 93941,
#              'grades': 675,
#              'could': 10645,
#              'your': 60637,
#              'real': 6577,
#              'Halloween': 258,
#              'costume': 346,
#              'who': 26259,
#              'would': 46389,
#              'was': 33570,
#              "Rasputin's": 1,
#              'involvement': 118,
#              'World': 1880,
#              'War': 2211,
#              '1': 8522,
#              'general': 2854,
#              'category': 1227,
#              'student': 7642,
#              'average': 4116,
#              'IQ': 1719,
#              "don't": 13890,
#              'deserve': 519,
#              'chance': 2200,
#              'government': 6017,
#              'health': 3200,
#              'issues': 1876,
#              'cause': 4057,
#              'severe': 470,
#              'dry': 786,
#              'itchy': 194,
#              'skin': 2422,
#              'Will': 13230,
#              'we': 34541,
#              'ever': 16112,
#              'problem': 3470,
#              'free': 6694,
#              'moment': 1425,
#              'explain': 2167,
#              'etiquette': 110,
#              'children': 4307,
#              'why': 16708,
#              "it's": 4369,
#              'important': 6569,
#              'saying': 1580,
#              'someone': 19496,
#              'Are': 26282,
#              'any': 34932,
#              'legal': 3144,
#              'concerns': 175,
#              'polygamous': 30,
#              '(': 50857,
#              'not': 42588,
#              'bigamist': 5,
#              ')': 50795,
#              'might': 1846,
#              'living': 4536,
#              'North': 3393,
#              'Carolina': 200,
#              'intentionally': 215,
#              'campy': 1,
#              'movies': 3209,
#              'In': 9187,
#              'event': 1180,
#              'revolution': 488,
#              'US': 11253,
#              'those': 3519,
#              'unarmed': 99,
#              'willing': 682,
#              'fight': 2718,
#              'armed': 365,
#              'greatest': 1359,
#              'examples': 4367,
#              'Butterfly': 18,
#              'Effect': 74,
#              'happened': 3183,
#              'throughout': 754,
#              'history': 4536,
#              'heavy': 789,
#              'trucks': 141,
#              'regulated': 119,
#              'highlights': 277,
#              'Bradley': 45,
#              "Cooper's": 5,
#              'acting': 1445,
#              'career': 5756,
#              'driving': 1073,
#              'distance': 1606,
#              'Philadelphia': 105,
#              'Boston': 323,
#              'emotionally': 703,
#              'detach': 34,
#              'myself': 4157,
#              'brother': 1089,
#              'stop': 8049,
#              'feeling': 2071,
#              'negative': 2214,
#              'when': 43393,
#              'sibling': 238,
#              'ciliary': 2,
#              'muscles': 461,
#              'accommodate': 53,
#              'become': 15318,
#              'astraunaut': 2,
#              'India': 28654,
#              'NASA': 479,
#              'which': 16588,
#              'classes': 1515,
#              'Donald': 3328,
#              'order': 3879,
#              'attack': 1585,
#              'Korea': 2628,
#              'December': 384,
#              'way': 18608,
#              'anal': 259,
#              'sex': 8078,
#              'without': 14855,
#              'lubricant': 34,
#              'Hyperloop': 36,
#              'mechanism': 448,
#              'possibility': 596,
#              'opening': 560,
#              'Allen': 443,
#              'institute': 1704,
#              'Delhi': 3560,
#              'about': 40494,
#              'Romania': 148,
#              'secret': 984,
#              'societies': 267,
#              'may': 1676,
#              'exist': 2683,
#              'college': 8631,
#              'possibly': 521,
#              'go': 13105,
#              'wrong': 4984,
#              'soil': 557,
#              'taken': 2358,
#              'street': 725,
#              'apart': 923,
#              'earthworms': 16,
#              'it': 121847,
#              'Tide': 31,
#              'Pods': 12,
#              'taste': 925,
#              'so': 33601,
#              "What's": 11221,
#              'most': 25938,
#              'challenging': 198,
#              'task': 325,
#              'Rajastan': 6,
#              "government's": 96,
#              'decision': 1162,
#              'bar': 620,
#              'courts': 171,
#              'taking': 3531,
#              'up': 16369,
#              'complaints': 86,
#              'against': 6554,
#              'public': 3470,
#              'servants': 77,
#              'approval': 256,
#              'When': 13125,
#              'will': 32280,
#              'allow': 1941,
#              'users': 1185,
#              'verified': 133,
#              'SAP': 584,
#              'ABAP': 48,
#              'recruitment': 388,
#              'drive': 1849,
#              'freshers': 323,
#              '2017': 7653,
#              'online': 9026,
#              'merchants': 41,
#              'accept': 2124,
#              'Skrill': 32,
#              'payment': 820,
#              'different': 10828,
#              'kinds': 569,
#              'lines': 838,
#              'their': 31365,
#              'meaning': 3479,
#              'My': 7447,
#              'stomach': 812,
#              'seems': 1400,
#              'bigger': 894,
#              '’': 19240,
#              'm': 3211,
#              'gassy': 9,
#              'constipated': 29,
#              'diarrhea': 224,
#              'eat': 4217,
#              'regural': 1,
#              'three': 2164,
#              '/': 33494,
#              'two': 7361,
#              'meals': 222,
#              'day': 8395,
#              's': 10343,
#              'happening': 785,
#              'loop': 238,
#              'through': 6997,
#              'SharePoint': 42,
#              'list': 2181,
#              'column': 226,
#              'using': 8550,
#              'JQuery': 7,
#              'JavaScript': 473,
#              'proble': 3,
#              'made': 7913,
#              'airbuses': 1,
#              'Do': 36165,
#              'deeper': 112,
#              'discussion': 247,
#              'question': 4609,
#              'Like': 496,
#              'back-and-forth': 1,
#              'debate': 436,
#              'answer': 4233,
#              'right': 7466,
#              'thing': 7666,
#              'reciprocated': 11,
#              'love': 9749,
#              'both': 4525,
#              'prior': 521,
#              'commitments': 26,
#              'mean': 12210,
#              'never': 6051,
#              'together': 2070,
#              'little': 1987,
#              'girl': 7735,
#              'rock': 557,
#              'star': 1027,
#              'film': 1654,
#              'long': 9892,
#              'did': 30584,
#              'take': 16673,
#              'Orson': 18,
#              'Scott': 170,
#              'Card': 153,
#              'convert': 1395,
#              "Ender's": 8,
#              'Game': 539,
#              'screenplay': 68,
#              'correct': 2406,
#              'UPSC': 1970,
#              'CSE': 2355,
#              'Mains': 1840,
#              'sheet': 447,
#              'story': 2937,
#              'started': 2327,
#              'Tinder': 319,
#              'Facebook': 4417,
#              'friendly': 577,
#              'JEE': 4328,
#              'main': 3651,
#              '5000': 294,
#              'rank': 4260,
#              'Muslim': 3408,
#              'women': 11184,
#              'reject': 372,
#              'burqua': 1,
#              'laptop': 2076,
#              'buy': 7728,
#              'under': 5218,
#              '35k': 26,
#              'Ahmedabad': 311,
#              'scientist': 764,
#              'said': 3122,
#              'this': 24134,
#              'copy': 718,
#              'another': 5156,
#              'mirror': 471,
#              'full': 3211,
#              'moon': 1045,
#              'rise': 875,
#              'at': 41787,
#              'sunset': 56,
#              'everywhere': 341,
#              'false': 852,
#              'case': 2552,
#              'filed': 206,
#              'practicing': 251,
#              'advocate': 181,
#              'innocent': 562,
#              'such': 6729,
#              'discharge': 331,
#              'leaders': 791,
#              'time': 20739,
#              'confident': 453,
#              'powerful': 1491,
#              'frank': 25,
#              'while': 10183,
#              'meeting': 656,
#              'other': 20409,
#              'app': 5022,
#              'help': 9054,
#              'bank': 3111,
#              'balance': 908,
#              'one': 29065,
#              'find': 15470,
#              'topic': 1152,
#              'his': 15797,
#              'her': 12591,
#              'Physics': 581,
#              'SL': 48,
#              'IA': 43,
#              'he': 17774,
#              'she': 8201,
#              'search': 1507,
#              'unique': 978,
#              'makes': 4829,
#              'eccentric': 32,
#              'Mexican': 429,
#              'equivalent': 739,
#              'Death': 295,
#              'Valley': 597,
#              'collector': 90,
#              'clients': 526,
#              'high': 7394,
#              'gems': 52,
#              'gain': 1899,
#              'air': 2459,
#              'aristocratic': 6,
#              'elegance': 9,
#              'defined': 363,
#              'John': 1343,
#              "Ireland's": 16,
#              'style': 1770,
#              'Americans': 4708,
#              'delegate': 32,
#              'responsibilities': 268,
#              'higher': 1904,
#              'entities': 88,
#              'politic': 12,
#              'powers': 565,
#              'big': 4298,
#              'companies': 4823,
#              'very': 6476,
#              'sided': 92,
#              'opinions': 596,
#              'seem': 2374,
#              'treated': 1143,
#              'like': 43605,
#              'sheeps': 11,
#              'origin': 868,
#              'pyramidal': 5,
#              'cultural': 834,
#              'asset': 205,
#              'greater': 668,
#              'education': 3138,
#              'less': 4601,
#              'gut': 118,
#              'instincts': 61,
#              'example': 2345,
#              'politics': 1535,
#              '64': 166,
#              'pleasing': 47,
#              'senses': 94,
#              'boost': 350,
#              'Hindi': 1804,
#              'vocabulary': 264,
#              'Day': 498,
#              'ICSE': 582,
#              'exam': 5267,
#              'Many': 301,
#              "seniors's": 1,
#              'survive': 1515,
#              'limited': 600,
#              'incomes': 31,
#              'satisfying': 101,
#              'live': 7685,
#              'besides': 752,
#              'RVing': 1,
#              'psychical': 5,
#              'differences': 2246,
#              'between': 21731,
#              'Renaissance': 138,
#              'Impressionism': 4,
#              'art': 1554,
#              'Have': 6521,
#              'been': 12458,
#              'faced': 717,
#              'traumatizing': 15,
#              'incident': 434,
#              'by': 37956,
#              'own': 7630,
#              'relatives': 279,
#              'hearing': 504,
#              'impaired': 66,
#              'students': 6514,
#              'aid': 468,
#              'eligible': 793,
#              'PSUs': 90,
#              'anyone': 7838,
#              'whom': 914,
#              "you'll": 106,
#              'indebted': 16,
#              'forever': 625,
#              'tuition': 285,
#              'fee': 954,
#              'Manipal': 672,
#              'University': 4813,
#              'M.tech': 67,
#              'Digital': 261,
#              'Electronics': 171,
#              'Advanced': 466,
#              'Communication': 125,
#              '14th': 76,
#              'FC': 138,
#              'delivered': 218,
#              'strong': 1821,
#              'push': 616,
#              'towards': 2443,
#              'true': 6743,
#              'federalism': 42,
#              'agree': 1244,
#              'Justify': 19,
#              'stand': 1349,
#              'book': 8359,
#              'Bible': 1302,
#              'put': 3650,
#              'appeal': 264,
#              'because': 8382,
#              'Easter': 91,
#              'supporting': 475,
#              'Jews': 2155,
#              'need': 11733,
#              'coached': 4,
#              'lie': 1041,
#              'anatomical': 20,
#              'similarities': 737,
#              'After': 1616,
#              'applying': 1056,
#              'visa': 2633,
#              'Germany': 2903,
#              'asked': 2396,
#              'exact': 655,
#              'travel': 3520,
#              'dates': 361,
#              'now': 9196,
#              'collect': 328,
#              'passport': 971,
#              'appointment': 220,
#              'Was': 3947,
#              'denied': 205,
#              'trusting': 67,
#              'only': 12513,
#              'if': 57718,
#              'trust': 1287,
#              'working': 5339,
#              'promo': 37,
#              'code': 2388,
#              'Hasnflare': 1,
#              'watching': 1253,
#              'Fox': 309,
#              'News': 314,
#              'make': 25190,
#              'stupid': 1679,
#              'Cesium': 2,
#              'preferred': 381,
#              'Rubidium': 3,
#              'Strontium': 1,
#              'atomic': 375,
#              'clocks': 53,
#              'more': 23952,
#              'mg': 201,
#              'Adderall': 85,
#              'per': 2821,
#              'spouse': 789,
#              'compare': 1400,
#              'me': 32400,
#              'ex': 2346,
#              'gained': 237,
#              'access': 1345,
#              'Medicaid': 62,
#              'ACA': 68,
#              'insurance': 1645,
#              'repealed': 54,
#              'possible': 12896,
#              'happily': 123,
#              'dreams': 972,
#              'comic': 432,
#              'company': 7970,
#              'artist': 648,
#              'publish': 483,
#              'universe': 2109,
#              'ideas': 2355,
#              'Would': 8860,
#              'hard': 4797,
#              'move': 3531,
#              'USA': 5029,
#              'Canada': 4658,
#              'biblical': 100,
#              'name': 7154,
#              'white': 5969,
#              'Europeans': 886,
#              'processor': 317,
#              'channels': 553,
#              'quiet': 283,
#              "they're": 1051,
#              'slightly': 271,
#              'upset': 500,
#              'angry': 923,
#              'livid': 3,
#              'outburst': 14,
#              'point': 3575,
#              'seeing': 1138,
#              'red': 1842,
#              'moving': 2022,
#              'Jhansi': 5,
#              'pet': 871,
#              'dog': 2998,
#              'breed': 354,
#              'suits': 217,
#              'extreme': 590,
#              'weather': 896,
#              'home': 5525,
#              'remedy': 217,
#              'remove': 2122,
#              'whiteheads': 23,
#              '8th': 271,
#              'British': 2785,
#              'English': 6796,
#              'mth': 2,
#              'new': 9828,
#              'really': 10456,
#              'culture': 2932,
#              'scope': 1754,
#              "I'm": 11964,
#              'v': 412,
#              'certain': 1720,
#              "I'll": 356,
#              'leave': 2970,
#              'eventually': 689,
#              'Should': 14949,
#              'malaria': 47,
#              'typhoid': 42,
#              'battlefield': 74,
#              'blunder': 22,
#              'Macro': 10,
#              'XE': 5,
#              'start': 11574,
#              'fixing': 116,
#              'after': 25960,
#              'breakup': 344,
#              'sure': 1296,
#              'adhere': 47,
#              'workout': 685,
#              'routine': 514,
#              'ads': 717,
#              'based': 3184,
#              'image': 1233,
#              'recognition': 307,
#              'Instagram': 2245,
#              'coaching': 2294,
#              'Durgesh': 2,
#              'Agrawal': 12,
#              'study': 7591,
#              "one's": 617,
#              'CBSE': 1724,
#              '12th': 2299,
#              'standard': 1391,
#              'scores': 489,
#              'future': 5452,
#              'come': 6762,
#              'out': 18498,
#              'around': 5097,
#              'opinion': 2727,
#              'above': 1094,
#              '50': 1669,
#              'apparently': 149,
#              'happy': 2275,
#              'income': 1870,
#              'But': 1021,
#              'obviously': 221,
#              'luck': 265,
#              'circumstance': 35,
#              'struggles': 133,
#              'hardships': 39,
#              'past': 2818,
#              ';': 1162,
#              'maybe': 373,
#              'intelligence': 1657,
#              'academic': 894,
#              'achievement': 182,
#              'ie': 111,
#              'mediocre': 125,
#              'features': 1312,
#              'nerve': 235,
#              'cell': 1631,
#              'bogota': 1,
#              'capital': 1097,
#              'Colombia': 121,
#              'city': 2524,
#              'Spain': 764,
#              'Ibiza': 11,
#              'autonomous': 192,
#              'community': 1536,
#              'American': 6526,
#              "EU's": 11,
#              'Horizon': 30,
#              '2020': 458,
#              'program': 3226,
#              'previews': 4,
#              'play': 4234,
#              'professional': 2045,
#              'theater': 159,
#              'mistakes': 650,
#              'math': 3667,
#              'calculations': 93,
#              'generate': 593,
#              'stress': 933,
#              'kind': 4968,
#              'hormonal': 61,
#              'rush': 109,
#              'orbit': 314,
#              'decay': 145,
#              'deal': 3872,
#              'shame': 218,
#              'self': 2166,
#              'loathing': 10,
#              'internalized': 10,
#              'homophobia': 64,
#              'homophobic': 148,
#              'country': 10221,
#              'surrounded': 113,
#              'equally': 278,
#              'friends': 5382,
#              'Explain': 354,
#              'calories': 627,
#              'sugar': 851,
#              'Can': 47497,
#              'switch': 1086,
#              'branches': 390,
#              'IIT': 3421,
#              'Goa': 468,
#              'year': 13411,
#              'junctional': 3,
#              'epithelium': 13,
#              'characterized': 123,
#              'Tanaka': 2,
#              'Giichi': 1,
#              'known': 4038,
#              'Jon': 330,
#              'snow': 269,
#              'say': 8895,
#              'dont': 872,
#              'Daenerys': 111,
#              'says': 2481,
#              'everybody': 427,
#              'likes': 1329,
#              'Where': 17398,
#              'reliable': 797,
#              'cabinet': 156,
#              'refinishing': 6,
#              'services': 2333,
#              'better': 14407,
#              'cool': 979,
#              'think': 23334,
#              'Pakistan': 3500,
#              'Every': 234,
#              "laptop's": 35,
#              'screen': 1130,
#              'pixelled': 1,
#              'exept': 5,
#              'videos': 1717,
#              'among': 1630,
#              'MS': 1771,
#              'Data': 622,
#              'Science': 1362,
#              'IUB': 2,
#              'MSCS': 13,
#              'UB': 6,
#              'UTD': 13,
#              'username': 153,
#              'KissAnime': 1,
#              'salt': 576,
#              'lamp': 127,
#              'Shaquille': 7,
#              "O'Neal": 7,
#              'prime': 788,
#              'define': 765,
#              'mature': 300,
#              'realtionship': 11,
#              'assistant': 583,
#              'sesssions': 1,
#              'court': 1079,
#              'Birla': 36,
#              'group': 2926,
#              'many': 21711,
#              'subsidiaries': 9,
#              'has': 23436,
#              'damn': 82,
#              'difficult': 2577,
#              'conservative': 916,
#              'perspective': 551,
#              'respected': 206,
#              'believed': 185,
#              'populated': 99,
#              'curious': 306,
#              'open-minded': 29,
#              '“': 3486,
#              'intelligent': 1192,
#              '”': 3529,
#              'individuals': 499,
#              'closed-minded': 6,
#              'bigots': 49,
#              'usonian': 2,
#              'easily': 1579,
#              'manipulated': 96,
#              'politicians': 740,
#              'mass': 2768,
#              'media': 4149,
#              'making': 4052,
#              'them': 16463,
#              'believe': 5135,
#              'lies': 642,
#              'outside': 1927,
#              'operator': 206,
#              'considered': 4579,
#              'harmful': 630,
#              'pan': 178,
#              'card': 3503,
#              'bilateral': 107,
#              'diplomatic': 197,
#              'foreign': 2420,
#              'relations': 714,
#              'Malawi': 16,
#              'AirBackupHelper': 1,
#              'startup': 1756,
#              'current': 3995,
#              'serial': 359,
#              'teenage': 533,
#              'school': 9476,
#              'legally': 906,
#              'worst': 2485,
#              'funny': 754,
#              'horrifying': 23,
#              'emotional': 977,
#              'support': 3869,
#              'animal': 1447,
#              'success': 1374,
#              'stories': 1365,
#              'give': 9144,
#              'private': 2534,
#              'lables': 2,
#              'owned': 323,
#              'Amazon': 2288,
#              'Flipkart': 311,
#              'Myntra': 58,
#              'checking': 266,
#              'physics': 2839,
#              'ISC': 356,
#              '2018': 6499,
#              'lenient': 38,
#              'Assuming': 213,
#              'actually': 4307,
#              'accelerate': 105,
#              'speed': 2734,
#              'light': 3365,
#              'reach': 1347,
#              'velocity': 718,
#              'accelerating': 69,
#              'fast': 2151,
#              'human': 5645,
#              'body': 4775,
#              'withstand': 80,
#              'Could': 4041,
#              'fall': 1955,
#              'asleep': 287,
#              'tied': 108,
#              'spinning': 163,
#              'wheel': 329,
#              'Justin': 291,
#              'Trudea': 1,
#              'worry': 398,
#              'fact': 1847,
#              'Fidel': 30,
#              'Castro': 46,
#              'father': 1887,
#              'rebut': 6,
#              'gay': 2684,
#              'misogynists': 14,
#              "won't": 1494,
#              'date': 3428,
#              'marry': 1829,
#              'just': 14528,
#              'vaginas': 39,
#              'enjoy': 1475,
#              'flogging': 5,
#              'form': 3696,
#              'judicial': 127,
#              'punishment': 527,
#              'still': 10893,
#              'United': 4011,
#              'States': 3392,
#              'traditional': 891,
#              'clothes': 1015,
#              'wear': 2951,
#              'vinegar': 165,
#              'pregnancy': 1038,
#              ...})

# %%
glove_emb_mean, glove_emb_std = -0.005838499, 0.48782197

# %%
# some config values 
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use

# %%
glove_embedding_matrix = np.random.normal(glove_emb_mean, glove_emb_std, (max_features, embed_size))

# %%
glove_oov = []
i = 0
for word in tqdm(vocab):
    if i >= max_features: break
    if word.lower() in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[word.lower()]
        i += 1
    else:
        glove_oov.append(word.lower())

print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=257897.0), HTML(value='')))
# percentage of oov of glove: 17.99%

# %%
glove_oov
# Out:
# ['dceu',
#  "china's",
#  'mahab',
#  'alshamsi',
#  "rasputin's",
#  "cooper's",
#  'astraunaut',
#  'hyperloop',
#  "what's",
#  'rajastan',
#  "government's",
#  "ender's",
#  "ireland's",
#  "seniors's",
#  'hasnflare',
#  "they're",
#  "i'm",
#  "i'll",
#  'durgesh',
#  "one's",
#  "eu's",
#  'giichi',
#  "laptop's",
#  'iub',
#  'mscs',
#  'kissanime',
#  'airbackuphelper',
#  'myntra',
#  'trudea',
#  "won't",
#  'su57',
#  'kvpy',
#  'taccetta',
#  'ayushman',
#  'tulamben',
#  'bmsce',
#  'itee',
#  "indonesia's",
#  "haven't",
#  "aren't",
#  'malrotated',
#  'ivanca',
#  'gynobasic',
#  "clinton's",
#  "professional's",
#  'aasi',
#  'acturial',
#  "he's",
#  'udemy',
#  "shouldn't",
#  "holy-shit-that's-a-monstrosity",
#  'scif',
#  'mclr',
#  'waterbridge',
#  'fadh',
#  'gurkas',
#  'ncell',
#  'supervillain-related',
#  'basavanagudi',
#  'beie',
#  "framer's",
#  ')=',
#  'arcsinx',
#  '2arcsinx',
#  "women's",
#  'auccant',
#  "elon's",
#  'neurosoft',
#  'cloudtms',
#  "you've",
#  "she's",
#  'lakshmibai',
#  'obcs',
#  "weren't",
#  'sendgrid',
#  "qur'an",
#  "tillman's",
#  'navaj',
#  '91.1-',
#  'terfs',
#  'toogit.com',
#  "someone's",
#  'ingineering',
#  "bachelor's",
#  'itpm',
#  "i've",
#  'aaip',
#  "god's",
#  'babaria',
#  "today's",
#  "she's",
#  "wasn't",
#  'hyperiq',
#  "person's",
#  "there's",
#  'kilpauk',
#  'mu-oet',
#  'panaya',
#  'budhisim',
#  'codechef',
#  "son's",
#  "asperger's",
#  'non-eu',
#  'dwaraka',
#  'kandam',
#  "isn't",
#  "world's",
#  'meetra',
#  'surik',
#  'nihilus',
#  "cubicolor's",
#  'bluemix',
#  'eecs',
#  "wouldn't",
#  'breechloaders',
#  'cryptocurrencies',
#  'fileboard',
#  'outreach.io',
#  'bahadurgarh',
#  'hedon',
#  'mookerjee',
#  'suvject',
#  'inifiitive',
#  'instacart',
#  'nmims',
#  'guangdong-style',
#  'ciaz',
#  'anti-multi-cultural',
#  'swarthy-skinned',
#  'houellebecq',
#  'winick',
#  'spinlab',
#  'hhl',
#  'coep',
#  'keshari',
#  'akasi',
#  'chubutenses',
#  'jujeños',
#  'ex-crush',
#  'amcat',
#  'flirtasioulsy',
#  "won't",
#  'chlorphenamine',
#  'bahubali',
#  'adhaar',
#  "who's",
#  'mhrd',
#  "what're",
#  "shouldn't",
#  'micromolecule',
#  'craik',
#  'zelenoff',
#  "uber's",
#  "friend's",
#  '-90-95',
#  '-55-60',
#  'harveer',
#  'aca-mandated',
#  'litecoin',
#  'estroy',
#  'propenoic',
#  "wouldn't",
#  "country's",
#  'autoencoders',
#  "else's",
#  "india's",
#  'dnc-clinton',
#  "rocketbolt's",
#  'kholi',
#  'bjyu',
#  'traki',
#  'sarso',
#  'chsl',
#  'adithya',
#  'hrudayam',
#  'slokam',
#  'mobilsocial.com',
#  "infj's",
#  "nf's",
#  "inf's",
#  'depandi',
#  'kubernetes',
#  'clickbait',
#  'chandivali',
#  'bibleman',
#  'kharijites',
#  "who's",
#  "what's",
#  'iqos',
#  'antamoeba',
#  "umayyad's",
#  'caugched',
#  'pahargunj',
#  "pawar's",
#  "kong's",
#  'britisher',
#  'egca',
#  'dgca',
#  'antritrust',
#  "economy's",
#  'mastersii',
#  'sedataious',
#  'http://avonresumes.com',
#  'hotstar',
#  'theoden',
#  'theodred',
#  'quorans',
#  'bullshit-sensitive',
#  'kyotou',
#  'utokyo',
#  'www.employxpert.com',
#  'spuul',
#  'dressly.com',
#  "ali's",
#  "putin's",
#  'whychoi',
#  'spreadtrum',
#  '36.how',
#  'non-east',
#  'iocl',
#  'linearty',
#  'hibor',
#  'إن',
#  'ّ',
#  'َ',
#  'أن',
#  "akhtar's",
#  'iiit-a',
#  'csam',
#  'iiit-d',
#  "mom's",
#  'celeborn',
#  'cuhk',
#  "maryand's",
#  'seirawan',
#  'triloki',
#  'ananye',
#  "quora's",
#  "ji'an",
#  'student.how',
#  'reinstitituted',
#  "america's",
#  'tapereamer',
#  'unacademy',
#  'opha',
#  'jinping',
#  'ecnalubma',
#  'tolmezzo',
#  "master's",
#  'lgbtiqas',
#  'baby-bell',
#  'airpods',
#  "company's",
#  'non-cisco',
#  'circuits.io',
#  "quine's",
#  "james's",
#  'https://twitter.com/derrickqlewis',
#  'fitjee',
#  'nintex',
#  'lazyapproval',
#  "russia's",
#  'asajj',
#  "hannity's",
#  'https://youtu.be/ef7xzpod6mo',
#  'redmi',
#  'rompope',
#  "club's",
#  'halam',
#  'kotlin',
#  'follic',
#  'paidpertweet',
#  'myeloblast',
#  "egypt's",
#  'hyper-nationalism',
#  'arakan',
#  'pcmb',
#  "congemi's",
#  'processar',
#  'graphophobia',
#  'misoprotal',
#  'www.inpeaks.com',
#  'nonpassive',
#  "israel's",
#  'www.philosophypedia.com',
#  'yanomami',
#  'huwaei',
#  'subsidiay',
#  'pregraduate',
#  "domino's",
#  'almyrantis',
#  "anakin's",
#  "hadn't",
#  'ascillation',
#  'paticle',
#  "isn't",
#  'euthrophication',
#  'southees',
#  "people's",
#  'blio',
#  'ps-i',
#  'diple',
#  'releasethememo',
#  'trumpers',
#  "twitter's",
#  'hhf',
#  'municial',
#  "city's",
#  'spoj',
#  'hackerearth',
#  'mensu',
#  'fyers',
#  'pgpem',
#  'apsrtc',
#  'vizianagaram',
#  'blueyeti',
#  'litecoin',
#  'ircc',
#  'anlasana',
#  "hasn't",
#  'd=',
#  '30m3',
#  'afcat',
#  'p18f4580',
#  'ethereum',
#  'p=',
#  "wix's",
#  'co3',
#  "conan's",
#  "eriksen's",
#  "men's",
#  "author's",
#  'group-d',
#  'rasia',
#  '1000xm2',
#  'grgm',
#  'c-ptsd',
#  "john's",
#  'brexit',
#  'sahsranamam',
#  "russell's",
#  '2457cm3',
#  'neman',
#  'lumosity',
#  "gowda's",
#  "trump's",
#  '₹',
#  'pacinian',
#  "jersey's",
#  'nsit',
#  'peenya',
#  'jiedushi',
#  'dysnasty',
#  'usict',
#  'retaline',
#  'carburising',
#  "lego's",
#  "sister's",
#  'anaar',
#  'bimaar',
#  "nri's",
#  'unnao',
#  'khatua',
#  "doyle's",
#  'intoiim',
#  'https://nypost.com/2018/05/30/vitamins-are-a-massive-waste-of-money-research-shows/',
#  'enjected',
#  'nda-ii',
#  'manit',
#  'pre-wwi',
#  'non-car-driving',
#  'womenizer',
#  'demigauge',
#  "hilary's",
#  'fttx',
#  'chrisley',
#  'hanes.com',
#  'groaking',
#  'facorite',
#  'hyooo',
#  "swift's",
#  'franed',
#  "disney's",
#  'georaphy',
#  "master's",
#  'mytectra',
#  'v154',
#  'q168',
#  'oces',
#  'dgfs',
#  'backpapers',
#  'desente',
#  'artitude',
#  'rwandans',
#  'bakchodi',
#  'zomato',
#  'separatist-states',
#  'rights-quora',
#  'asscending',
#  'motivonal',
#  'mofett',
#  'aluva',
#  "ronaldo's",
#  'fullering',
#  'androis',
#  'applicats',
#  'cnpd',
#  'ommition',
#  'vnit',
#  'lamport',
#  'chitrangada',
#  "blalock's",
#  "california's",
#  "cohen's",
#  'tentaculata',
#  'lupercal',
#  'ximb',
#  "nepal's",
#  'inclinement',
#  'rosenwald',
#  'god-humanity',
#  'non-molecular',
#  "earth's",
#  'waffen-ss',
#  'bhakts',
#  'vaikunta',
#  'cycsts',
#  'greber',
#  'antineutron',
#  'swach',
#  '1x1m',
#  'judeophiles',
#  "there's",
#  '1only',
#  'opeartion',
#  'nlsiu',
#  "mother's",
#  'gusau',
#  'okene',
#  'fodio',
#  'idga',
#  'mh17',
#  'mh370',
#  'y-linked',
#  'y-chromosomes',
#  '8|',
#  'pgre',
#  'matketing',
#  '\u200b',
#  'qoura',
#  'wittyfeed',
#  'careee',
#  'walras',
#  'isidor',
#  "rabi's",
#  "php's",
#  'maslows',
#  'delphix',
#  "britain's",
#  'un-closable',
#  'cicuits',
#  'microsoft-github',
#  'arebest',
#  'field-energy',
#  "girl's",
#  "car's",
#  'stealthgear',
#  "sr's",
#  'moutin',
#  "driscoll's",
#  'escon',
#  'jupyterlab',
#  'decizions',
#  'anti-china',
#  "mendel's",
#  'vajiram',
#  "poisson's",
#  "hino's",
#  'glonass',
#  "schutzenberger's",
#  'neo-darwinian',
#  'loksabha',
#  'shudh',
#  'genrat',
#  'kanhaiya',
#  'gatw',
#  'gyaration',
#  "raynaud's",
#  'nerest',
#  'dhinchak',
#  "mellon's",
#  '):',
#  'sinosphere',
#  'francosphere',
#  'indosphere',
#  'basketballcourt',
#  'demi-leigh',
#  'nel-peters',
#  "man's",
#  'optane',
#  'mullayanagiri',
#  'non-vegetarianism',
#  "couldn't",
#  "matter's",
#  "mueller's",
#  'iiest',
#  'shibpur',
#  "voyeur's",
#  'abdella',
#  'bhakts',
#  'potentiometar',
#  'apllead',
#  'rocketspace',
#  'ryzen',
#  "sharp's",
#  'kalanick',
#  'perfectil',
#  "doctor's",
#  'worldbreaker',
#  "panelist's",
#  'mid-debate',
#  'nahso',
#  'na2so4',
#  'timesspark',
#  'wikitribune',
#  'ecgc',
#  'dsce',
#  'cowpics',
#  'spoj',
#  'rigil',
#  'kentaurus',
#  'dapoxtine',
#  'hyper-track',
#  'elektrotechnik',
#  'micca',
#  'non-blockinh',
#  'ssbs',
#  'irodov',
#  'krotov',
#  "eisner's",
#  'self-capability',
#  'zerodha',
#  'sayajirao',
#  "rabbit's",
#  'unikoin',
#  'piezoelectronics',
#  'timehop',
#  'biologiste',
#  "college's",
#  "user's",
#  "she'd",
#  'upwork',
#  'jan-ken-pon',
#  'simstarted',
#  '113/180',
#  'i3indya',
#  'sadhguru',
#  'cath.church',
#  'isil',
#  'mactree',
#  "prim's",
#  'kanodia',
#  'subjectwise',
#  '..',
#  'mmaw',
#  '_0',
#  '͜',
#  'ʖ',
#  "korea's",
#  "verizon's",
#  "marey's",
#  "infidel's",
#  'sci-hub',
#  'hooker--we',
#  "fan's",
#  'em-field',
#  'bachus',
#  'coinbase',
#  "american's",
#  'zamasu',
#  "nyu's",
#  'syzygium',
#  "palmer's",
#  'dardanian',
#  'steemit',
#  'kiheitai',
#  '奇兵隊',
#  'proffessed',
#  'interactivecorp',
#  "crocodile's",
#  'drepssison',
#  'engineet',
#  "college's",
#  'nimcet',
#  's-stage',
#  'meghnad',
#  'relationship-taste',
#  'olmpic',
#  'iapt',
#  'kammalar',
#  'yadhavar',
#  'nchmct',
#  "devil's",
#  'laravel',
#  'yercaud',
#  "edison's",
#  'iisc',
#  'iiser',
#  'naria',
#  'bactera',
#  'removw',
#  'multi-photographer',
#  "baby's",
#  'xiaohui',
#  'covidien',
#  'rimar',
#  'timan',
#  'hydroxied',
#  'rajapaksa',
#  'modiji',
#  'tamilans',
#  "partner's",
#  'transabled',
#  'biid',
#  '180ah',
#  'ruettiger',
#  'carpentary',
#  "valentine's",
#  'reingest',
#  'cecotropes',
#  "chicago's",
#  'tifr',
#  "kristofferson's",
#  'e-ray',
#  'bar-one',
#  'singer-sees',
#  'kiss-have',
#  'scorpious',
#  "obama's",
#  "thiel's",
#  'turkmens',
#  'pro-eugenics',
#  'ehats',
#  'iitb',
#  'ramón',
#  'jiménez',
#  'solu-medrol',
#  'from-electricity-to-vibration',
#  "google's",
#  'nsep',
#  'nrotc',
#  "hilton's",
#  "hasn't",
#  "bangladesh's",
#  'rohingya',
#  'tirupattur',
#  'hadnshakes',
#  'cvryptocurrency',
#  'cifar',
#  'perditor',
#  "aren't",
#  'shogi-related',
#  'ghazwa-e-hind',
#  'johanessburg',
#  'caelic',
#  'disease.how',
#  'entpreneural',
#  'kharar',
#  'gökturks',
#  'ncrypto',
#  'french-occupied',
#  "germany's",
#  'vi8',
#  'shigaraki',
#  'authorea',
#  'sharelatex',
#  'antigod',
#  "could've",
#  "human's",
#  'diffrrent',
#  'mandhana',
#  'manafort',
#  "muslim's",
#  'brocklehurst',
#  'sjmsom',
#  'misogynistical',
#  'nirbhya',
#  'gudiya',
#  'snapdeal.com',
#  'manufucturing',
#  'snefru',
#  'meidum',
#  'dashur',
#  "griffin's",
#  'mulâtresse',
#  'arthimatic',
#  "warmbier's",
#  'medreps',
#  "x'ers",
#  "sjw's",
#  "school's",
#  'magoosh',
#  'rvce',
#  'odoo',
#  "luftwaffe's",
#  'vabroom',
#  'framelayout',
#  'problemss',
#  "parker's",
#  'debritone',
#  'mylogenous',
#  "rice's",
#  "france's",
#  'chandipur',
#  'madhyamik',
#  "men's",
#  'plecosthomus',
#  'paytm',
#  'elitmus',
#  'sasken',
#  "dosn't",
#  '0-538',
#  'vijayanagar',
#  'lillis',
#  "ron's",
#  'enotions',
#  'basilone',
#  "foster's",
#  "berkeley's",
#  '\u202a',
#  '\u202c',
#  'kapashera',
#  'dgvcl',
#  'raúl',
#  'wadō-ryū',
#  'casperjs',
#  "boyfriend's",
#  'mediahub',
#  'mgims',
#  'wardha',
#  'haunani',
#  'tableys',
#  'vishishtadvaitha',
#  'boisar',
#  'svnit',
#  'peditrian',
#  'irrdet',
#  'bhubaneshwar',
#  'iiitd',
#  'acadians',
#  'dictorship',
#  "usa's",
#  'ft-fm',
#  'interjectors',
#  'westline',
#  'elasticy',
#  "anthony's",
#  'mizoz',
#  'non-mizo',
#  'sailour',
#  'mandiant',
#  'crowdstrike',
#  'tracheole',
#  'ashamedh',
#  'jspiders',
#  'qspiders',
#  "chad's",
#  '100/366',
#  'litrpg',
#  "gamora's",
#  'zen-whoberians',
#  'boeng',
#  'yssy',
#  'maharashtrians',
#  'non-marathi',
#  'bitonnect',
#  'ligal',
#  'haryanvis',
#  'unamic',
#  'blocknet',
#  'altcoin',
#  "how's",
#  'ocasio-cortez',
#  "mother's",
#  'deangerous',
#  'computrr',
#  'anelectrical',
#  "evm's",
#  'anti-greek',
#  'wingmans',
#  "mooc's",
#  'uceed',
#  "microsoft's",
#  'pergade',
#  'dissocation',
#  'undergraduation',
#  'munjal',
#  'brahmanism',
#  'conincides',
#  'productful',
#  'powerfulquantum',
#  'undersdaing',
#  '33a3',
#  'baccalaurrate',
#  'reently',
#  "hawking's",
#  "court's",
#  "o'hagan",
#  'yashodhra',
#  'dahiya',
#  'judeo-christianity',
#  'abrahmic',
#  'sports-hatchback',
#  'arifa',
#  'ethereum',
#  'ing-wen',
#  'belousov-zhabotinsky',
#  'trezor',
#  'dexs',
#  "winans's",
#  'mallaya',
#  'xlri',
#  'physiotheraphy',
#  "let's",
#  'tmau',
#  "bike's",
#  'speedbreakers',
#  'navd',
#  'vks',
#  "newton's",
#  'technology.am',
#  "mitchell's",
#  "washington's",
#  'globalfoundries',
#  'entitlments',
#  "lennon's",
#  'departmrnt',
#  "woman's",
#  'lacture',
#  'intertel',
#  'rajarhat',
#  'manjrekar',
#  '131841',
#  'saprotite',
#  'abzug',
#  'dáithí',
#  'metaldays',
#  'acountant',
#  'pichai',
#  'qadiyani',
#  'mridula',
#  'koshy',
#  "chanukya's",
#  'fundamentalen',
#  'люис',
#  'refregerated',
#  'sindri',
#  'fachhochschule',
#  'burckle',
#  'thuas',
#  'm430',
#  'fighbetweenheartandmindaboutthout',
#  'liud',
#  'l1a',
#  'kollata',
#  "maker's",
#  "einstein's",
#  'cjjd',
#  'bahubali',
#  'ct00',
#  'etoos',
#  'kirigakure',
#  'jinchurikis',
#  "trump's",
#  "pakistan's",
#  "laurence's",
#  "officer's",
#  "ranchi's",
#  'pgdhrm',
#  'doriath',
#  'saeros',
#  'chacolate',
#  "naruto's",
#  'less-than-stealthy',
#  'adult-killing',
#  'gujaratis',
#  'altzhiemers',
#  "it'll",
#  'pattikalyan',
#  'bstat',
#  'combiantorics',
#  'tamirlargal',
#  'tamirlnadu',
#  'dcac',
#  'explnatauon',
#  "gibb's",
#  'machala',
#  'nptel',
#  '20.5937',
#  '78.9629',
#  'meanif',
#  'bhms',
#  'nh3reacts',
#  'syrio',
#  'forel',
#  'offerup',
#  "franken's",
#  'dushka',
#  'jee-mains',
#  '128977',
#  'consdeva',
#  'genderfluid',
#  'mlm-wise',
#  'ds418j',
#  'ds1517',
#  'lockheed-martin',
#  'isckon',
#  'b.pharma',
#  'ceragem',
#  'hubli-dharwad',
#  'sharedpreferences',
#  "iim's",
#  "iim's",
#  'overprocrastinate',
#  'dejavús',
#  'plazzo',
#  'examinor',
#  'afro-asiatic',
#  "cauchy's",
#  "bse's",
#  'edogawa-ku',
#  'analhak',
#  'galgotia',
#  "oprah's",
#  'eklavya',
#  '8:',
#  'india-pakistan',
#  "runescape's",
#  "internet's",
#  'capicorn',
#  "guy's",
#  'npcil',
#  "byju's",
#  'feku',
#  'lyft',
#  'uwgpa',
#  '4⁴⁸',
#  '687194a6735',
#  'prayanamas',
#  'chatzigiannis',
#  "peyronie's",
#  'siachen',
#  'magyars',
#  'sucrets',
#  'dueterte',
#  'sabharwal',
#  "amc's",
#  'ra-apist',
#  'slawomir',
#  'biela',
#  'zuari',
#  '10:25-',
#  'kuratko',
#  'rewi',
#  "maniapoto's",
#  'arefuel',
#  "nehru's",
#  "we've",
#  'roem',
#  'brexit',
#  'hbbtv',
#  'smarter--a',
#  "health's",
#  'http://www.latimes.com/business/hiltzik/la-fi-hiltzik-trump-university-20161121-story.html',
#  'mckc',
#  'faurecia',
#  'cyclogy',
#  'aphg',
#  'narender',
#  "slay's",
#  'sociolinguistique',
#  'favguard.com',
#  'brick-house',
#  'database-heavy',
#  "tile's",
#  "queen's",
#  'ambedkarites',
#  'u0001f646',
#  "patanjali's",
#  'plekhanov',
#  'head-strikes',
#  "parent's",
#  'aplicability',
#  'catrgory',
#  'yuja',
#  "wang's",
#  "machete's",
#  'indeted',
#  'jee-advanced',
#  "newmark's",
#  ...]

# %% [markdown]
# https://wikidocs.net/21707

# %%
# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.stem import PorterStemmer
s=PorterStemmer()
from nltk.stem import LancasterStemmer
l=LancasterStemmer()
from nltk.stem import WordNetLemmatizer
n=WordNetLemmatizer()

glove_oov = []
i = 0
for word in tqdm(vocab):
    if i >= max_features: break

    tmp = word
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.lower()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = word.upper()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.capitalize()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = s.stem(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = l.stem(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = n.lemmatize(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    

    else:
        glove_oov.append(word)
    
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=257897.0), HTML(value='')))
# percentage of oov of glove: 10.59%

# %%
glove_oov
# Out:
# ['DCEU',
#  "China's",
#  'mahab',
#  'AlShamsi',
#  "Rasputin's",
#  "Cooper's",
#  'astraunaut',
#  "What's",
#  "government's",
#  "Ender's",
#  "Ireland's",
#  "seniors's",
#  'Hasnflare',
#  "they're",
#  "one's",
#  "EU's",
#  'Giichi',
#  "laptop's",
#  'KissAnime',
#  'AirBackupHelper',
#  "won't",
#  'su57',
#  'Taccetta',
#  'BMSCE',
#  "Indonesia's",
#  "haven't",
#  "aren't",
#  'malrotated',
#  'Ivanca',
#  'gynobasic',
#  "Clinton's",
#  "professional's",
#  "he's",
#  "shouldn't",
#  "Holy-Shit-That's-A-Monstrosity",
#  'Gurkas',
#  'supervillain-related',
#  "Framer's",
#  ')=',
#  'arcsinx',
#  '2arcsinx',
#  "women's",
#  'auccant',
#  "Elon's",
#  'Neurosoft',
#  'CloudTMS',
#  "you've",
#  "she's",
#  "weren't",
#  "Qur'an",
#  "Tillman's",
#  '91.1-',
#  'toogit.com',
#  "someone's",
#  "bachelor's",
#  "God's",
#  "today's",
#  "She's",
#  "wasn't",
#  'hyperIQ',
#  "person's",
#  "There's",
#  'MU-OET',
#  'budhisim',
#  "son's",
#  "Asperger's",
#  "isn't",
#  "world's",
#  "Cubicolor's",
#  'Bluemix',
#  "Wouldn't",
#  'breechloaders',
#  'cryptocurrencies',
#  'Fileboard',
#  'Outreach.io',
#  'suvject',
#  'inifiitive',
#  'Instacart',
#  'Guangdong-style',
#  'ciaz',
#  'anti-multi-cultural',
#  'swarthy-skinned',
#  'SpinLab',
#  'Chubutenses',
#  'Jujeños',
#  'ex-crush',
#  'flirtasioulsy',
#  "Won't",
#  "who's",
#  "What're",
#  "Shouldn't",
#  'micromolecule',
#  "Uber's",
#  "friend's",
#  '-90-95',
#  '-55-60',
#  'ACA-mandated',
#  'litecoin',
#  'Estroy',
#  'Propenoic',
#  "wouldn't",
#  "country's",
#  'Autoencoders',
#  "else's",
#  "India's",
#  'DNC-Clinton',
#  "Rocketbolt's",
#  'bjyu',
#  'sarso',
#  'Hrudayam',
#  'slokam',
#  'mobilsocial.com',
#  "INFJ's",
#  "NF's",
#  "INF's",
#  'Kubernetes',
#  'clickbait',
#  "Who's",
#  "what's",
#  'IQOS',
#  'Antamoeba',
#  "Umayyad's",
#  'caugched',
#  'pahargunj',
#  "Pawar's",
#  "Kong's",
#  'Antritrust',
#  "economy's",
#  'mastersii',
#  'Sedataious',
#  'http://avonresumes.com',
#  'hotstar',
#  'bullshit-sensitive',
#  'KyotoU',
#  'UTokyo',
#  'www.employxpert.com',
#  'dressly.com',
#  "Ali's",
#  "Putin's",
#  'Whychoi',
#  '36.How',
#  'non-East',
#  'Linearty',
#  'إن',
#  'ّ',
#  'َ',
#  'أن',
#  "Akhtar's",
#  'IIIT-A',
#  'IIIT-D',
#  "mom's",
#  "Maryand's",
#  'Triloki',
#  'Ananye',
#  "Quora's",
#  'student.How',
#  'reinstitituted',
#  "America's",
#  'tapereamer',
#  'unacademy',
#  'ECNALUBMA',
#  "master's",
#  'LGBTIQAs',
#  'Baby-bell',
#  'Airpods',
#  "company's",
#  'circuits.io',
#  "Quine's",
#  "James's",
#  'https://twitter.com/DerrickQLewis',
#  'LazyApproval',
#  "Russia's",
#  "Hannity's",
#  'https://youtu.be/EF7XzPOD6Mo',
#  'Redmi',
#  'rompope',
#  "club's",
#  'paidpertweet',
#  'myeloblast',
#  "Egypt's",
#  'hyper-nationalism',
#  "Congemi's",
#  'graphophobia',
#  'Misoprotal',
#  'www.inpeaks.com',
#  'nonpassive',
#  "Israel's",
#  'www.philosophypedia.com',
#  'Huwaei',
#  'subsidiay',
#  'pregraduate',
#  "Domino's",
#  'Almyrantis',
#  "Anakin's",
#  "hadn't",
#  'ascillation',
#  'paticle',
#  "Isn't",
#  'Euthrophication',
#  "people's",
#  'ReleaseTheMemo',
#  "Twitter's",
#  "city's",
#  'HackerEarth',
#  'mensu',
#  'PGPEM',
#  'blueyeti',
#  'Litecoin',
#  'Anlasana',
#  "hasn't",
#  'd=',
#  '30m3',
#  'p18f4580',
#  'p=',
#  "Wix's",
#  "Conan's",
#  "Eriksen's",
#  "Men's",
#  "author's",
#  'group-d',
#  '1000XM2',
#  'GRGM',
#  "John's",
#  'brexit',
#  'Sahsranamam',
#  "Russell's",
#  '2457cm3',
#  "Gowda's",
#  "Trump's",
#  '₹',
#  "Jersey's",
#  'jiedushi',
#  'dysnasty',
#  'USICT',
#  'retaline',
#  "LEGO's",
#  "sister's",
#  "NRI's",
#  "Doyle's",
#  'intoIIM',
#  'https://nypost.com/2018/05/30/vitamins-are-a-massive-waste-of-money-research-shows/',
#  'enjected',
#  'NDA-II',
#  'non-car-driving',
#  'demigauge',
#  "Hilary's",
#  'groaking',
#  'facorite',
#  'hyooo',
#  "Swift's",
#  "Disney's",
#  'georaphy',
#  "Master's",
#  'mytectra',
#  'v154',
#  'q168',
#  'DGFS',
#  'backpapers',
#  'bakchodi',
#  'separatist-states',
#  'rights-Quora',
#  'asscending',
#  'motivonal',
#  'Mofett',
#  "Ronaldo's",
#  'CNPD',
#  "Blalock's",
#  "California's",
#  "Cohen's",
#  'tentaculata',
#  "Nepal's",
#  'God-Humanity',
#  'non-molecular',
#  "earth's",
#  'cycsts',
#  'antineutron',
#  '1x1m',
#  'Judeophiles',
#  "there's",
#  '1only',
#  'Opeartion',
#  "Mother's",
#  'MH17',
#  'MH370',
#  '8|',
#  'PGRE',
#  'matketing',
#  '\u200b',
#  'qoura',
#  'Wittyfeed',
#  "Rabi's",
#  "PHP's",
#  "Britain's",
#  'un-closable',
#  'Microsoft-Github',
#  'areBest',
#  'field-energy',
#  "girl's",
#  "Car's",
#  'Stealthgear',
#  "Sr's",
#  "Driscoll's",
#  'JupyterLab',
#  "Mendel's",
#  'Vajiram',
#  "Poisson's",
#  "Hino's",
#  "Schutzenberger's",
#  'GATW',
#  'gyaration',
#  "Raynaud's",
#  'nerest',
#  'Dhinchak',
#  "Mellon's",
#  '):',
#  'Francosphere',
#  'Indosphere',
#  'basketballcourt',
#  'Demi-Leigh',
#  'Nel-Peters',
#  "man's",
#  'Mullayanagiri',
#  "couldn't",
#  "Matter's",
#  "Mueller's",
#  'IIEST',
#  "Voyeur's",
#  'potentiometar',
#  'apllead',
#  'rocketspace',
#  'Ryzen',
#  "Sharp's",
#  "doctor's",
#  "panelist's",
#  'mid-debate',
#  'nahso',
#  'na2so4',
#  'TimesSpark',
#  'Wikitribune',
#  'DSCE',
#  'COWPICS',
#  'dapoxtine',
#  'hyper-track',
#  'non-blockinh',
#  'Irodov',
#  "Eisner's",
#  'self-capability',
#  'Zerodha',
#  "rabbit's",
#  'Unikoin',
#  'piezoelectronics',
#  "College's",
#  "user's",
#  "she'd",
#  'Upwork',
#  'Jan-ken-pon',
#  'simstarted',
#  '113/180',
#  'i3indya',
#  'Cath.church',
#  "prim's",
#  'subjectwise',
#  '..',
#  'MMAW',
#  '_0',
#  '͜',
#  'ʖ',
#  "Korea's",
#  "Verizon's",
#  "Marey's",
#  "infidel's",
#  'Sci-Hub',
#  'hooker--we',
#  "fan's",
#  'EM-field',
#  'Coinbase',
#  "American's",
#  'Zamasu',
#  "NYU's",
#  "Palmer's",
#  'Steemit',
#  'Kiheitai',
#  '奇兵隊',
#  'proffessed',
#  "Crocodile's",
#  'drepssison',
#  'Engineet',
#  "college's",
#  'S-stage',
#  'relationship-taste',
#  'olmpic',
#  'kammalar',
#  'yadhavar',
#  "Devil's",
#  "Edison's",
#  'removw',
#  'multi-photographer',
#  "baby's",
#  "partner's",
#  '180Ah',
#  "Valentine's",
#  'reingest',
#  'cecotropes',
#  "Chicago's",
#  "Kristofferson's",
#  'E-ray',
#  'bar-one',
#  'singer-sees',
#  'kiss-have',
#  "Obama's",
#  "Thiel's",
#  'pro-eugenics',
#  'from-electricity-to-vibration',
#  "Google's",
#  "Hilton's",
#  "Hasn't",
#  "Bangladesh's",
#  'hadnshakes',
#  'cvryptocurrency',
#  'perditor',
#  "Aren't",
#  'shogi-related',
#  'Ghazwa-e-Hind',
#  'Johanessburg',
#  'disease.how',
#  'entpreneural',
#  'Gökturks',
#  'NCRYPTO',
#  'French-occupied',
#  "Germany's",
#  'vi8',
#  'Authorea',
#  'ShareLaTeX',
#  'AntiGod',
#  "could've",
#  "human's",
#  'diffrrent',
#  'Mandhana',
#  "Muslim's",
#  'SJMSOM',
#  'nirbhya',
#  'manufucturing',
#  "Griffin's",
#  'mulâtresse',
#  'arthimatic',
#  "Warmbier's",
#  'MedReps',
#  "SJW's",
#  "school's",
#  'Odoo',
#  "Luftwaffe's",
#  'VaBroom',
#  'framelayout',
#  "Parker's",
#  'debritone',
#  'mylogenous',
#  "Rice's",
#  "France's",
#  "men's",
#  'Plecosthomus',
#  'eLitmus',
#  "dosn't",
#  '0-538',
#  "Ron's",
#  "Foster's",
#  "Berkeley's",
#  '\u202a',
#  '\u202c',
#  'DGVCL',
#  'Wadō-ryū',
#  "boyfriend's",
#  'tableys',
#  'vishishtadvaitha',
#  'irrdet',
#  'IIITD',
#  "USA's",
#  'FT-FM',
#  'elasticy',
#  "Anthony's",
#  'Mizoz',
#  'Non-Mizo',
#  'Sailour',
#  'Crowdstrike',
#  'tracheole',
#  'ashamedh',
#  'Jspiders',
#  'Qspiders',
#  "Chad's",
#  '100/366',
#  'LitRPG',
#  "Gamora's",
#  'Zen-Whoberians',
#  'non-Marathi',
#  'Bitonnect',
#  'Blocknet',
#  'altcoin',
#  "How's",
#  'Ocasio-Cortez',
#  "mother's",
#  'deangerous',
#  'anElectrical',
#  "EVM'S",
#  "MOOC's",
#  "Microsoft's",
#  'Pergade',
#  'dissocation',
#  'undergraduation',
#  'conincides',
#  'powerfulquantum',
#  'undersdaing',
#  '33a3',
#  'baccalaurrate',
#  "Hawking's",
#  "Court's",
#  'Yashodhra',
#  'Abrahmic',
#  'sports-hatchback',
#  "Winans's",
#  "Let's",
#  "Bike's",
#  'Speedbreakers',
#  "Newton's",
#  'technology.am',
#  "Mitchell's",
#  "Washington's",
#  'entitlments',
#  "Lennon's",
#  'departmrnt',
#  "woman's",
#  '131841',
#  'saprotite',
#  'Metaldays',
#  "Chanukya's",
#  'Люис',
#  'refregerated',
#  'fighbetweenheartandmindaboutthout',
#  'liud',
#  'kollata',
#  "Maker's",
#  "Einstein's",
#  'CJJD',
#  'ct00',
#  "trump's",
#  "Pakistan's",
#  "Laurence's",
#  "officer's",
#  "Ranchi's",
#  'PGDHRM',
#  'Saeros',
#  'chacolate',
#  "Naruto's",
#  'less-than-stealthy',
#  'adult-killing',
#  'altzhiemers',
#  "it'll",
#  'pattikalyan',
#  'BSTAT',
#  'Tamirlargal',
#  'Tamirlnadu',
#  'explnatauon',
#  "Gibb's",
#  '20.5937',
#  '78.9629',
#  'NH3reacts',
#  'OfferUp',
#  "Franken's",
#  'JEE-Mains',
#  '128977',
#  'ConsDeva',
#  'genderfluid',
#  'MLM-wise',
#  'DS418j',
#  'DS1517',
#  'Isckon',
#  'b.pharma',
#  'sharedpreferences',
#  "IIM'S",
#  "IIM's",
#  'overprocrastinate',
#  'dejavús',
#  'plazzo',
#  "Cauchy's",
#  "BSE's",
#  'Edogawa-ku',
#  'Analhak',
#  "Oprah's",
#  '8:',
#  "Runescape's",
#  "internet's",
#  'Capicorn',
#  "guy's",
#  "Byju's",
#  'feku',
#  'UWGPA',
#  '4⁴⁸',
#  '687194a6735',
#  'prayanamas',
#  'Chatzigiannis',
#  "Peyronie's",
#  'Dueterte',
#  "AMC's",
#  'Ra-apist',
#  '10:25-',
#  "Maniapoto's",
#  'areFuel',
#  "Nehru's",
#  "we've",
#  'Brexit',
#  'smarter--a',
#  "Health's",
#  'http://www.latimes.com/business/hiltzik/la-fi-hiltzik-trump-university-20161121-story.html',
#  'MCKC',
#  'cyclogy',
#  'APHG',
#  "Slay's",
#  'Favguard.com',
#  'brick-house',
#  'database-heavy',
#  "tile's",
#  "Queen's",
#  'Ambedkarites',
#  'U0001f646',
#  "Patanjali's",
#  'head-strikes',
#  "parent's",
#  'catrgory',
#  "Wang's",
#  "machete's",
#  'JEE-Advanced',
#  "Newmark's",
#  "X's",
#  'poison-filled',
#  "Cobourg's",
#  '12,2017',
#  "yesterday's",
#  'locopilot',
#  "Rubik's",
#  "Filipino's",
#  "date's",
#  "boy's",
#  'AAPtards',
#  "civil's",
#  'Huckabee-Sanders',
#  'fast-packing',
#  '1050ti',
#  'Buddisht',
#  'requriedIn',
#  'dhuryodhana',
#  'darawe',
#  'JSSATE',
#  "PG's",
#  'CTO-Office',
#  "They're",
#  "Buddhist's",
#  'Avdhesh',
#  "Singh's",
#  'Eksperto',
#  "Oryx's",
#  'घ',
#  'झ',
#  'ढ',
#  'ध',
#  'भ',
#  'bhallaldev',
#  "Paul's",
#  'Montbeliarde',
#  "INSEAD's",
#  'E-MBA',
#  "Findlay's",
#  'crypto-currency',
#  'Bakalibus',
#  "Apollyon's",
#  'tickect',
#  'fullform',
#  'cryptovirology',
#  'Scadinavian',
#  'gateschool',
#  "Bartomeu's",
#  'Velverde',
#  'BAPM',
#  'patchhandle',
#  'Dentacoin',
#  'Zebpay',
#  'Cryptopia',
#  "Tolstoy's",
#  'kanjimasu',
#  'naranaikedo',
#  'divyansh',
#  'sikarwar',
#  "child's",
#  "community's",
#  "API's",
#  'contact.His',
#  'constant-memory',
#  'global-memory',
#  'Cabba',
#  "Dany's",
#  'Menakkettu',
#  '25000AED',
#  "Luke's",
#  'Gboard',
#  'Ung-Yong',
#  "There'd",
#  'mathmetics',
#  'Sahishnuta',
#  'mithocondrial',
#  "n'era",
#  'TaskBot',
#  'MetaBot',
#  'IQBot',
#  'calmato',
#  'worker-to-land',
#  '32e200dx',
#  'Itutor',
#  'apogamy',
#  'monotonocity',
#  'CA3130',
#  'Automate.io',
#  'M445',
#  '940MX',
#  '5:22-',
#  "Kyle's",
#  'dysfuntinal',
#  'narendr',
#  'roolcage',
#  'Aktu',
#  "IIT's",
#  'endurolast',
#  'surviving-till-now',
#  'sanctuarious',
#  'C2070',
#  "Elemer's",
#  "Xavier's",
#  'HackerRank',
#  'Doscos',
#  "transformer's",
#  'Tanahk',
#  'semetisism',
#  "Haven't",
#  'texila',
#  '4.5-',
#  'schme',
#  "Musk's",
#  'curroption',
#  'hamonica',
#  "state's",
#  'provavility',
#  'humitarian',
#  "Howl's",
#  'هاپو',
#  'پیشی',
#  'LZ129',
#  'lithromantics',
#  'tqwl',
#  'Rapphael',
#  "parents's",
#  '403t',
#  'JioFi',
#  'PSTCL',
#  'ты',
#  'вы',
#  "Jon's",
#  'CIWG',
#  'zarget',
#  'hotjar',
#  "Houlihan's",
#  'disavatage',
#  "Khan's",
#  'Triplebyte',
#  "Modi's",
#  'breathing.Why',
#  '18:86',
#  "Shivaji's",
#  "fresher's",
#  "NASA's",
#  "Apple's",
#  "Hayworth's",
#  'dailyhunt',
#  'Ishvalan',
#  'universalition',
#  'disadvanatage',
#  'spherocytes',
#  'goatfuckers',
#  'Theory-Half',
#  'Theory-opinions',
#  'HashFlare.io',
#  'srmjee',
#  "Nipkow's",
#  'plouing',
#  'Opentoonz',
#  'SellerPrime',
#  'aldep',
#  'SPCPL',
#  "birthday's",
#  "devil's",
#  'NEAR-SIMILAR',
#  'sklearn',
#  'sodalime',
#  'alkanoate',
#  'Jreviews',
#  "lacan's",
#  'Nopile',
#  'goomo.com',
#  '3.607',
#  'XGBoostRegressor',
#  'xgboost',
#  "Gulliver's",
#  "you'd",
#  '\xad',
#  'cabnot',
#  'V-sit',
#  "PRC's",
#  'gravititaional',
#  "you'reee",
#  'vist-worthy',
#  "Assange's",
#  "Lowe's",
#  "wife's",
#  'Perfluoromethyldecalin',
#  'School.Its',
#  "Physician's",
#  'hinjawadi',
#  'TestDAF',
#  'HealthIQ',
#  'D.C.on',
#  "Quezon's",
#  'abtrail',
#  'ExpressConnect',
#  "Housley's",
#  'sigmaplot',
#  'zuclopenthixol',
#  'Genophobia',
#  'Coitophobia',
#  "Nigeria's",
#  'envyJews',
#  'Outreachy',
#  'Seahud',
#  'trignometric',
#  'adityanath',
#  '113/200',
#  'muoet',
#  'Non-SPA',
#  'acylglycerol',
#  "Pine's",
#  "Shatner's",
#  '};',
#  "let's",
#  'FOSTIIMA',
#  '2015,2016',
#  'yogasanam',
#  "Muller's",
#  'unexempted',
#  'pre-hypothyroid',
#  "Serbia's",
#  "Stannis's",
#  "Storm's",
#  "YouTube's",
#  "Salman's",
#  'mantelyta',
#  'commumist',
#  'denabank',
#  'Madhunashiniwati',
#  'Roboute',
#  '200,000-',
#  "Caeser's",
#  "Brady's",
#  'Baahubali',
#  "Mainline's",
#  'B.A.LLB',
#  'elctron',
#  'releassed',
#  'edWisor.com',
#  'leucodermic',
#  "Assad's",
#  'あたまわるい',
#  "Elizabeth's",
#  'alt-right',
#  "we're",
#  'ununbium',
#  'copernisium',
#  'melophobia',
#  "McDonald's",
#  'ex-Pakistan',
#  'Irainians',
#  "Dalton's",
#  'differebtial',
#  'p_model',
#  '3471cc',
#  'polyetherene',
#  'OnePlus',
#  "Stalin's",
#  'charmendar',
#  'SAAGIRID',
#  'ASFAD',
#  'particiy',
#  'ftre',
#  "Gandhi's",
#  "father's",
#  '-56/55',
#  '936000',
#  "Levy's",
#  'cryptocurreny',
#  "Magazine's",
#  '1300D',
#  "Wasn't",
#  'x²',
#  '350 2014',
#  'prpr',
#  "driver's",
#  "D'jango",
#  "Husserl's",
#  'ralwy',
#  'ibarurishamibare',
#  '知音',
#  '30ties',
#  'RedMi',
#  'Alshami',
#  'Vaatu',
#  'Raava',
#  "They've",
#  'to-boot',
#  "had've",
#  "Melville's",
#  'BBA.LL',
#  "monoxide's",
#  'qx-r',
#  'displaystyel',
#  'Pakthunkwa',
#  'Christian.Can',
#  'quarintined',
#  'temble',
#  'dimble',
#  'simbly',
#  "Timbaland's",
#  'one-press',
#  'InstaPot',
#  "husband's",
#  "MacFarlane's",
#  'adverd',
#  'drainadrainage',
#  'a069',
#  'euthaniasia',
#  'Saradanagar',
#  'Vanasthalipuram',
#  "grandmother's",
#  'Xamarin.Android',
#  "Centre's",
#  "language's",
#  '31-03-',
#  'prespitate',
#  "Australia's",
#  "We're",
#  'develepoments',
#  'hemmorroids',
#  '1mrk',
#  'dropng',
#  'yr.what',
#  '5-10-',
#  'bahadurpur',
#  'P.Bahadur',
#  'Zangnan',
#  'ZnCl',
#  'Adityanath',
#  "Un's",
#  'cotx',
#  'cosecx',
#  "Rusoff's",
#  'https://paperial.com/',
#  'land.Where',
#  'CanFin',
#  'warm-tone',
#  '4:6-',
#  'UGVCL',
#  'frienfly',
#  "ain't",
#  'Unacademy',
#  'ummaya',
#  'lullabi.com',
#  'electropotential',
#  'case.what',
#  "Brown's",
#  "Potter's",
#  "element's",
#  'CH2CHO',
#  'off-in',
#  '14846:2000',
#  'eKYC',
#  'clch',
#  '2c6h4ch2c',
#  'MSc-MTech',
#  '. ..',
#  "Islam's",
#  'Garrix',
#  "Moto's",
#  'Halogen-metal',
#  'iodoketones',
#  'extiguisher',
#  'D7200',
#  '18-140',
#  '18-300',
#  ...]

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }

# %%
def get_known_contractions(embed):
    known = []
    for contract in contraction_mapping:
        if contract in embed:
            known.append(contract)
    return known

# %%
get_known_contractions(glove_embedding)
# Out:
# ["can't",
#  "'cause",
#  "didn't",
#  "doesn't",
#  "don't",
#  "I'd",
#  "I'll",
#  "I'm",
#  "I've",
#  "it's",
#  "ma'am",
#  "o'clock",
#  "that's",
#  "you'll",
#  "you're"]

# %%
import re

def tokenize(sent):
    known_contractions = get_known_contractions(glove_embedding)
    contraction_keys = set(contraction_mapping.keys()) - set(known_contractions)
    for contraction in contraction_keys:
        sent = re.sub(contraction, contraction_mapping[contraction], sent)
        sent = re.sub(contraction.capitalize(), contraction_mapping[contraction].capitalize(), sent)
        sent = re.sub(contraction.upper(), contraction_mapping[contraction].upper(), sent)
    return tweet_tknzr.tokenize(sent)

# %%
tokenize("You've got it")
# Out:
# ['You', 'have', 'got', 'it']

# %%
"you've" in contraction_mapping
# Out:
# True

# %%
"you've".capitalize()
# Out:
# "You've"

# %%
sentences = train_df["question_text"].fillna("_na_").progress_apply(tokenize).values
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1175509.0), HTML(value='')))

# %%
vocab = build_vocab(sentences)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1175509.0), HTML(value='')))

# %%
from nltk.stem import PorterStemmer
s=PorterStemmer()
from nltk.stem import LancasterStemmer
l=LancasterStemmer()
from nltk.stem import WordNetLemmatizer
n=WordNetLemmatizer()

glove_oov = {}
i = 0
for word in tqdm(vocab):
    if i >= max_features: break

    tmp = word
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.lower()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = word.upper()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.capitalize()
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = s.stem(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = l.stem(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = n.lemmatize(word)
    if tmp in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    if word in contraction_mapping.keys():
        tmp =  contraction_mapping[word]    
        if tmp in glove_embedding:
            glove_embedding_matrix[i] = glove_embedding[tmp]
            i += 1
            continue


    else:
        glove_oov[word] = i
    
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=257764.0), HTML(value='')))
# percentage of oov of glove: 3.13%

# %%
vocab

# %%
glove_oov
# Out:
# {"Trump's": 1117,
#  '..': 1949,
#  '\u200b': 2001,
#  "today's": 2091,
#  "someone's": 2116,
#  "one's": 2346,
#  "India's": 2353,
#  "people's": 2454,
#  "world's": 3083,
#  "women's": 3157,
#  'cryptocurrencies': 3157,
#  'Brexit': 3181,
#  "person's": 3243,
#  "China's": 3552,
#  'Redmi': 3750,
#  "country's": 3959,
#  'ा': 4099,
#  "master's": 4265,
#  "America's": 4317,
#  "men's": 4361,
#  "friend's": 4898,
#  "Quora's": 4972,
#  "bachelor's": 4982,
#  "Obama's": 5004,
#  "Earth's": 5136,
#  "God's": 5239,
#  "man's": 5264,
#  '₹': 5391,
#  "woman's": 5395,
#  "company's": 5511,
#  "else's": 5667,
#  "father's": 5942,
#  "children's": 5947,
#  "Master's": 6005,
#  "child's": 6199,
#  "Modi's": 6320,
#  "mother's": 6374,
#  "girl's": 6573,
#  "dog's": 6679,
#  "McDonald's": 6782,
#  "Google's": 6805,
#  "wife's": 7229,
#  "other's": 7704,
#  "Newton's": 7891,
#  "Korea's": 7984,
#  "husband's": 8001,
#  "Russia's": 8027,
#  'OnePlus': 8100,
#  "driver's": 8204,
#  "Hitler's": 8239,
#  'ि': 8441,
#  "Asperger's": 8450,
#  "Israel's": 8454,
#  '(8': 8478,
#  "earth's": 8507,
#  "year's": 8675,
#  "Pakistan's": 8827,
#  "Canada's": 9014,
#  "boyfriend's": 9098,
#  "government's": 9149,
#  "everyone's": 9246,
#  "son's": 9276,
#  'demonetisation': 9321,
#  "girlfriend's": 9463,
#  'GDPR': 9531,
#  '्': 9609,
#  'BNBR': 9622,
#  'Coinbase': 9655,
#  "Einstein's": 9663,
#  "Apple's": 9671,
#  'े': 9765,
#  "sister's": 9793,
#  "Japan's": 10205,
#  'Adityanath': 10267,
#  "Amazon's": 10284,
#  "Iran's": 10337,
#  "King's": 10431,
#  "cat's": 10438,
#  "Jehovah's": 10439,
#  "Clinton's": 10462,
#  "Alzheimer's": 10528,
#  'Boruto': 10544,
#  'IIEST': 10741,
#  'DCEU': 10997,
#  'alt-right': 11052,
#  "daughter's": 11166,
#  "Women's": 11172,
#  "student's": 11191,
#  "Bachelor's": 11289,
#  "Xavier's": 11341,
#  "Musk's": 11341,
#  "brother's": 11353,
#  "life's": 11409,
#  "Qur'an": 11415,
#  "Putin's": 11513,
#  "mom's": 11620,
#  "USA's": 11643,
#  'Machedo': 11660,
#  "Valentine's": 11835,
#  'anti-Trump': 11865,
#  'र': 11878,
#  "UK's": 11915,
#  "parent's": 11967,
#  "layman's": 12002,
#  "phone's": 12115,
#  ')=': 12173,
#  "Germany's": 12206,
#  "A's": 12279,
#  "baby's": 12357,
#  'Qoura': 12451,
#  'LNMIIT': 12456,
#  "Gandhi's": 12517,
#  "BJP's": 12527,
#  'न': 12536,
#  'ी': 12585,
#  'Zerodha': 12627,
#  "Britain's": 12746,
#  'Upwork': 12750,
#  "partner's": 12752,
#  "anyone's": 12920,
#  '}=': 12955,
#  "Jackson's": 12980,
#  "University's": 12990,
#  'क': 12997,
#  "Facebook's": 13133,
#  "Australia's": 13246,
#  "People's": 13426,
#  "guy's": 13549,
#  "IIT's": 13562,
#  "Khan's": 13566,
#  "family's": 13598,
#  'Doklam': 13609,
#  "nation's": 13673,
#  '):': 13703,
#  "human's": 13709,
#  'Unacademy': 13748,
#  'NICMAR': 13799,
#  "car's": 13825,
#  'Vajiram': 13875,
#  "Marvel's": 13967,
#  "dad's": 13971,
#  "Singapore's": 14091,
#  'MUOET': 14143,
#  'ल': 14157,
#  "doctor's": 14200,
#  'म': 14263,
#  "somebody's": 14315,
#  "Men's": 14586,
#  'Litecoin': 14773,
#  "Tesla's": 14885,
#  'HackerRank': 15236,
#  "computer's": 15256,
#  "Kavalireddi's": 15320,
#  "John's": 15400,
#  'altcoin': 15429,
#  'Baahubali': 15461,
#  "President's": 15504,
#  "Miller's": 15535,
#  'Awdhesh': 15573,
#  'eLitmus': 15639,
#  "individual's": 15689,
#  "ex's": 15690,
#  'ो': 15792,
#  'AlShamsi': 15821,
#  "Disney's": 15834,
#  'Ryzen': 15843,
#  "school's": 15852,
#  "Stalin's": 15890,
#  'altcoins': 15947,
#  "teacher's": 16014,
#  "California's": 16063,
#  "user's": 16070,
#  "Shakespeare's": 16133,
#  'r-aping': 16156,
#  'coinbase': 16197,
#  ':(': 16202,
#  "Hawking's": 16306,
#  "boy's": 16316,
#  "Singh's": 16317,
#  "writer's": 16353,
#  ');': 16420,
#  'MU-OET': 16528,
#  'ं': 16637,
#  'SGSITS': 16747,
#  '_0': 16832,
#  '8:': 16856,
#  '8/': 17065,
#  'Amazon.in': 17072,
#  "laptop's": 17076,
#  "Indonesia's": 17076,
#  "IIM's": 17125,
#  "Rubik's": 17135,
#  "state's": 17141,
#  'SRMJEE': 17181,
#  'त': 17198,
#  'BMSCE': 17363,
#  "Mueller's": 17395,
#  "fresher's": 17429,
#  'ह': 17481,
#  "body's": 17511,
#  "Plato's": 17524,
#  "PSU's": 17537,
#  "Tolkien's": 17549,
#  'Skripal': 17652,
#  'litecoin': 17664,
#  'स': 17759,
#  'MHCET': 17770,
#  'BIPC': 17774,
#  "iPhone's": 17774,
#  "US's": 17810,
#  "Hillary's": 17812,
#  "Assassin's": 17864,
#  '़': 17909,
#  '8)': 17923,
#  'OBC-NCL': 17966,
#  "Microsoft's": 18016,
#  'x²': 18047,
#  "Brown's": 18059,
#  "Potter's": 18059,
#  "party's": 18076,
#  'द': 18094,
#  'ु': 18094,
#  "Man's": 18159,
#  '=(': 18193,
#  "Africa's": 18251,
#  'Swachh': 18269,
#  "Indian's": 18315,
#  "American's": 18362,
#  "Smith's": 18449,
#  "Europe's": 18460,
#  'Truecaller': 18501,
#  "patient's": 18531,
#  "Batman's": 18594,
#  'Zebpay': 18727,
#  "Muhammad's": 18788,
#  "Netflix's": 18837,
#  "Harry's": 18876,
#  'SRMJEEE': 18876,
#  "society's": 18931,
#  'Gurugram': 18987,
#  "Uber's": 19007,
#  "EVM'S": 19046,
#  "Queen's": 19061,
#  'ै': 19124,
#  "crush's": 19164,
#  'Alshamsi': 19259,
#  "Thor's": 19334,
#  'upwork': 19376,
#  "city's": 19409,
#  '/8': 19507,
#  'TensorFlow': 19551,
#  "brain's": 19552,
#  "Mexico's": 19552,
#  "website's": 19560,
#  "Moore's": 19672,
#  "Grey's": 19680,
#  "animal's": 19771,
#  'clickbait': 19807,
#  "France's": 19835,
#  "Islam's": 19895,
#  'Ravula': 19952,
#  "Superman's": 19960,
#  "Victoria's": 19975,
#  'Chromecast': 19998,
#  'ज': 20108,
#  "Turkey's": 20109,
#  "Year's": 20140,
#  "Darwin's": 20182,
#  "college's": 20238,
#  "MNC's": 20386,
#  "Jesus's": 20427,
#  "Lee's": 20567,
#  "TV's": 20582,
#  'य': 20587,
#  "England's": 20587,
#  "Parkinson's": 20617,
#  "Johnson's": 20642,
#  "neighbor's": 20668,
#  "Mother's": 20715,
#  "NASA's": 20777,
#  "YouTube's": 20789,
#  "Krishna's": 20846,
#  '#MeToo': 20869,
#  "CEO's": 20885,
#  'Alt-Right': 20928,
#  "Noah's": 21052,
#  ':/': 21113,
#  "Kant's": 21158,
#  "Paul's": 21278,
#  "do's": 21320,
#  "sun's": 21414,
#  'Bittrex': 21478,
#  "Samsung's": 21489,
#  'microservices': 21521,
#  'RLWL': 21561,
#  "bank's": 21648,
#  'demonitisation': 21652,
#  "artist's": 21652,
#  "PC's": 21672,
#  "author's": 21751,
#  'USICT': 21751,
#  'Irodov': 21766,
#  'प': 21885,
#  "uncle's": 21958,
#  'Koinex': 21982,
#  'Quora.com': 22019,
#  'B.Des': 22141,
#  'unacademy': 22277,
#  "Swift's": 22283,
#  'Zamasu': 22302,
#  "Delhi's": 22441,
#  "team's": 22466,
#  "president's": 22567,
#  "NIT's": 22581,
#  "Trudeau's": 22623,
#  '\ufeff': 22629,
#  'Trumpcare': 22644,
#  "kid's": 22753,
#  "Maxwell's": 22758,
#  '#metoo': 22771,
#  "Spain's": 22802,
#  "Washington's": 22923,
#  'JioFi': 22948,
#  'ग': 23005,
#  "May's": 23050,
#  "Taylor's": 23073,
#  "network's": 23079,
#  "Jordan's": 23101,
#  "Perry's": 23117,
#  'pro-Trump': 23121,
#  'NLUs': 23142,
#  "moon's": 23151,
#  "Malaysia's": 23171,
#  'SSC-CGL': 23179,
#  'Trump-Russia': 23207,
#  "Father's": 23218,
#  "client's": 23251,
#  "Comey's": 23322,
#  'Tensorflow': 23382,
#  "Egypt's": 23494,
#  "Leia's": 23618,
#  "cousin's": 23665,
#  'HBTU': 23671,
#  'Codeforces': 23684,
#  'USB-C': 23691,
#  "week's": 23789,
#  'Patreon': 23868,
#  "Stanford's": 23898,
#  'VSSUT': 23911,
#  'FTRE': 23917,
#  "Graham's": 23919,
#  "Allen's": 23970,
#  "beginner's": 24024,
#  "Nazi's": 24032,
#  "Snapchat's": 24033,
#  "Napoleon's": 24040,
#  "B's": 24041,
#  "Freud's": 24051,
#  'Despacito': 24130,
#  'LBSNAA': 24142,
#  "citizen's": 24161,
#  'XeF': 24168,
#  "Quoran's": 24179,
#  'MHTCET': 24195,
#  'brexit': 24225,
#  "Muslim's": 24250,
#  "SJW's": 24252,
#  'undergraduation': 24260,
#  'genderfluid': 24267,
#  "Byju's": 24270,
#  'incels': 24301,
#  'ब': 24337,
#  'JCPOA': 24356,
#  "SpaceX's": 24382,
#  'musical.ly': 24390,
#  'tensorflow': 24396,
#  "Jupiter's": 24429,
#  "planet's": 24443,
#  'IGDTUW': 24444,
#  'Whydo': 24525,
#  'IIT-JAM': 24527,
#  'zebpay': 24621,
#  'Zenfone': 24634,
#  "Martin's": 24638,
#  'Arrowverse': 24658,
#  'chapterwise': 24669,
#  "Stark's": 24753,
#  'Kalpit': 24822,
#  'HackerEarth': 24874,
#  "Naruto's": 24932,
#  "Dalton's": 24971,
#  'EFLU': 24987,
#  '️': 24987,
#  "Harvard's": 24987,
#  "Kushner's": 24991,
#  'Xiomi': 25006,
#  "Bush's": 25009,
#  "character's": 25101,
#  "Who'd": 25113,
#  "another's": 25155,
#  "Markle's": 25173,
#  "Wendy's": 25196,
#  "Allah's": 25216,
#  "Eminem's": 25231,
#  'P=': 25308,
#  'PMAY': 25320,
#  "Kennedy's": 25345,
#  "Karna's": 25362,
#  "owner's": 25449,
#  "Wilson's": 25453,
#  "Machedo's": 25483,
#  "Snow's": 25551,
#  'AKTU': 25603,
#  "Voldemort's": 25607,
#  "Erdogan's": 25627,
#  'Kubernetes': 25646,
#  "Domino's": 25652,
#  "Ronaldo's": 25657,
#  'IIITD': 25688,
#  "API's": 25717,
#  "Brazil's": 25774,
#  '-1/2': 25812,
#  "World's": 25821,
#  "Vietnam's": 25897,
#  'OneDrive': 25914,
#  "Lincoln's": 25988,
#  'Kavalireddi': 26124,
#  "Joe's": 26150,
#  "grandfather's": 26204,
#  "Vishwanathan's": 26222,
#  'D3300': 26284,
#  "religion's": 26295,
#  "university's": 26300,
#  'Sarahah': 26337,
#  'nanodegree': 26390,
#  "Kejriwal's": 26420,
#  'WannaCry': 26476,
#  "Ireland's": 26521,
#  'Odoo': 26589,
#  "X's": 26612,
#  'fullform': 26621,
#  "Lowe's": 26641,
#  "Bannon's": 26684,
#  'ू': 26716,
#  "Churchill's": 26791,
#  "site's": 26905,
#  '2017/2018': 26920,
#  '\\:': 26957,
#  'Kaneki': 26993,
#  "spouse's": 27137,
#  "engineer's": 27148,
#  "Buddha's": 27205,
#  'Hotstar': 27234,
#  "Messi's": 27247,
#  "Asia's": 27357,
#  'करन': 27369,
#  'Kovind': 27376,
#  'twinflame': 27437,
#  '|=': 27447,
#  "who'd": 27475,
#  'Instacart': 27492,
#  'hotstar': 27500,
#  'p=': 27511,
#  "Nepal's": 27520,
#  'Steemit': 27537,
#  'च': 27684,
#  'DeepMind': 27698,
#  "cow's": 27724,
#  "Marx's": 27746,
#  'Mbappe': 27803,
#  "Children's": 27835,
#  "Greece's": 27846,
#  "Nolan's": 27882,
#  "that'll": 27892,
#  "Jio's": 27901,
#  'LNCT': 27921,
#  "Sharma's": 27926,
#  "Christ's": 27932,
#  'Theranos': 27943,
#  "Hindu's": 27944,
#  "Intel's": 27987,
#  'zerodha': 28073,
#  'EXTC': 28089,
#  "Mary's": 28144,
#  "gf's": 28144,
#  'BS-MS': 28162,
#  "Jinping's": 28166,
#  "I'am": 28172,
#  "Beethoven's": 28195,
#  "Bell's": 28243,
#  '2k17': 28246,
#  "C's": 28253,
#  "Nixon's": 28311,
#  "learner's": 28334,
#  'Nanodegree': 28366,
#  'Jungkook': 28370,
#  'Strzok': 28401,
#  '্': 28419,
#  'Cryptocurrencies': 28453,
#  "Bitcoin's": 28472,
#  'ra-apist': 28501,
#  "Saturn's": 28506,
#  'x_': 28527,
#  'React.js': 28538,
#  "Party's": 28552,
#  'ra-aping': 28560,
#  "bf's": 28574,
#  "Federer's": 28575,
#  "Cohen's": 28626,
#  'MH370': 28631,
#  "trump's": 28673,
#  "yesterday's": 28684,
#  "devil's": 28706,
#  "Muller's": 28717,
#  "Assad's": 28721,
#  'ftre': 28725,
#  "Jabba's": 28745,
#  "Stephen's": 28762,
#  "Orwell's": 28769,
#  "game's": 28811,
#  'व': 28852,
#  'koinex': 28875,
#  "Watson's": 28895,
#  'Neuralink': 28936,
#  "Instagram's": 28965,
#  'MMMUT': 28972,
#  "month's": 29061,
#  "II's": 29101,
#  'Drumpf': 29127,
#  "Cersei's": 29145,
#  "Robinson's": 29161,
#  'Bitfinex': 29180,
#  "Rome's": 29285,
#  'SSCBS': 29292,
#  "Peterson's": 29294,
#  "DC's": 29311,
#  "Vinci's": 29373,
#  "IQ's": 29406,
#  'Awdesh': 29499,
#  'Plancess': 29514,
#  "Zuckerberg's": 29538,
#  "plot's": 29545,
#  "Argentina's": 29565,
#  "Mao's": 29603,
#  'NEET-UG': 29603,
#  'Kattankulathur': 29639,
#  'Padmaavat': 29686,
#  "house's": 29687,
#  'Veerwal': 29690,
#  "Robert's": 29697,
#  "Euler's": 29707,
#  "Hashimoto's": 29709,
#  'internshala': 29710,
#  'MSQE': 29724,
#  "West's": 29728,
#  'VITMEE': 29732,
#  "god's": 29739,
#  "Night's": 29745,
#  "Anakin's": 29776,
#  'MH17': 29795,
#  'Dhinchak': 29797,
#  "Court's": 29835,
#  "officer's": 29842,
#  "Nehru's": 29848,
#  "Nigeria's": 29877,
#  "Venezuela's": 29962,
#  "Handmaid's": 30015,
#  "member's": 30040,
#  "administration's": 30045,
#  "media's": 30059,
#  "Italy's": 30069,
#  "tomorrow's": 30080,
#  "Lenin's": 30084,
#  "software's": 30120,
#  "MIT's": 30146,
#  "Bernoulli's": 30156,
#  'jiofi': 30192,
#  "Young's": 30208,
#  "customer's": 30235,
#  'AirPods': 30243,
#  'KMnO': 30271,
#  "Poe's": 30278,
#  "Viswanathan's": 30283,
#  "Kohli's": 30328,
#  "Kalam's": 30334,
#  'BMSIT': 30334,
#  "aircraft's": 30341,
#  "Vader's": 30347,
#  "Aristotle's": 30351,
#  "military's": 30353,
#  "Vishnu's": 30358,
#  "David's": 30407,
#  "Sun's": 30410,
#  "narcissist's": 30422,
#  "Green's": 30425,
#  'TISSNET': 30438,
#  "ICO's": 30482,
#  'USACO': 30528,
#  "Pro's": 30674,
#  'demonitization': 30692,
#  'AILET': 30698,
#  "Roosevelt's": 30727,
#  "Macron's": 30734,
#  'া': 30786,
#  'UPESEAT': 30788,
#  "Moody's": 30796,
#  "Campbell's": 30841,
#  'covfefe': 30848,
#  'Killmonger': 30855,
#  "employee's": 30868,
#  "York's": 30872,
#  "Fox's": 30877,
#  "Barcelona's": 30892,
#  'a_': 30938,
#  'mhtcet': 30964,
#  "eye's": 31000,
#  "Berkeley's": 31091,
#  'crypto-currency': 31136,
#  'srmjee': 31160,
#  "grandmother's": 31187,
#  "Un's": 31193,
#  'D7200': 31197,
#  'post-Brexit': 31199,
#  'TQWL': 31204,
#  "system's": 31204,
#  'GSTIN': 31206,
#  "Pascal's": 31241,
#  'BALLB': 31242,
#  "Francisco's": 31280,
#  "Drake's": 31289,
#  "Buffett's": 31327,
#  "Navy's": 31349,
#  '_1': 31380,
#  '_2': 31380,
#  "institute's": 31380,
#  'Vue.js': 31392,
#  "Ng's": 31406,
#  'Kefla': 31440,
#  "victim's": 31479,
#  "court's": 31491,
#  "Shah's": 31534,
#  "Mumbai's": 31537,
#  "Bohr's": 31550,
#  "London's": 31560,
#  'Zhihu': 31609,
#  "Dumbledore's": 31623,
#  "School's": 31624,
#  "Chopin's": 31642,
#  "Arabia's": 31651,
#  "IBM's": 31665,
#  'sarahah': 31693,
#  "history's": 31734,
#  'PGDBF': 31758,
#  'wumao': 31759,
#  "Zealand's": 31787,
#  'Kainerugaba': 31839,
#  "Diana's": 31844,
#  "Bach's": 31870,
#  'Brexiteers': 31956,
#  'Warmbier': 31963,
#  '{8': 31975,
#  "plant's": 32012,
#  'Jupyter': 32023,
#  "enemy's": 32034,
#  "Hell's": 32037,
#  'ipill': 32084,
#  'Padmavat': 32093,
#  "Levi's": 32196,
#  "Macy's": 32200,
#  "Netanyahu's": 32239,
#  "candidate's": 32243,
#  "Kernan's": 32249,
#  'ड': 32358,
#  "FDR's": 32364,
#  "Shiva's": 32403,
#  "Walker's": 32432,
#  "City's": 32496,
#  '្': 32504,
#  "EU's": 32507,
#  "Kong's": 32523,
#  'DSCE': 32566,
#  "Thiel's": 32581,
#  '\u202a': 32589,
#  "Anthony's": 32594,
#  "language's": 32678,
#  'AIMCAT': 32704,
#  'LHMC': 32720,
#  "Kakashi's": 32745,
#  "seller's": 32752,
#  "Rose's": 32794,
#  "Franklin's": 32797,
#  "Tourette's": 32833,
#  "Crohn's": 32861,
#  'MobiKwik': 32892,
#  "night's": 32892,
#  "Spotify's": 32948,
#  "Sweden's": 32948,
#  'Feku': 32948,
#  'sayat.me': 32965,
#  "Ambani's": 32965,
#  'Poloniex': 32967,
#  "Christian's": 33015,
#  "pro's": 33040,
#  "Satan's": 33042,
#  'Oneplus': 33053,
#  "developer's": 33057,
#  'Taehyung': 33116,
#  'RGIPT': 33133,
#  "Kumar's": 33166,
#  "Kapoor's": 33180,
#  "Murphy's": 33183,
#  "McCain's": 33193,
#  "Heisenberg's": 33208,
#  'DigitalOcean': 33214,
#  "Mozart's": 33264,
#  "Goku's": 33267,
#  "bird's": 33268,
#  "aunt's": 33275,
#  "grandma's": 33283,
#  "NRA's": 33322,
#  "Ra's": 33345,
#  "Black's": 33358,
#  "Patrick's": 33390,
#  'crypto-currencies': 33417,
#  'KGMU': 33467,
#  'Brexiters': 33501,
#  "professor's": 33530,
#  "JFK's": 33536,
#  "actor's": 33554,
#  'ट': 33640,
#  "humanity's": 33713,
#  "Bible's": 33747,
#  "Lord's": 33760,
#  'overbrace': 33800,
#  "Dhoni's": 33820,
#  "Cook's": 33823,
#  "INTP's": 33898,
#  "movie's": 33925,
#  "Taiwan's": 33955,
#  "manager's": 33986,
#  'HomePod': 34067,
#  'Bitconnect': 34083,
#  "engine's": 34103,
#  "universe's": 34112,
#  'IIIT-D': 34170,
#  "Devil's": 34228,
#  "Edison's": 34229,
#  "Chicago's": 34231,
#  "Lennon's": 34252,
#  'JEE-Mains': 34262,
#  "Luke's": 34281,
#  "HBO's": 34404,
#  'B.des': 34409,
#  'श': 34426,
#  "stranger's": 34435,
#  '7700k': 34438,
#  'FZ25': 34442,
#  "Institute's": 34449,
#  "Greene's": 34490,
#  "Scott's": 34510,
#  "Skywalker's": 34512,
#  "player's": 34551,
#  "Mussolini's": 34590,
#  "Snape's": 34612,
#  'MAKAUT': 34692,
#  'MPSTME': 34707,
#  "Merkel's": 34714,
#  "Wright's": 34762,
#  "nature's": 34773,
#  "Freddy's": 34777,
#  "con's": 34793,
#  "gov't": 34862,
#  "Kohl's": 34880,
#  "Kim's": 34899,
#  "Wolverine's": 34908,
#  'narcissit': 35092,
#  "Syria's": 35104,
#  "Herbert's": 35177,
#  "BBC's": 35206,
#  'GE14': 35249,
#  "Minister's": 35256,
#  "NGO's": 35268,
#  "camera's": 35296,
#  "object's": 35394,
#  'DoorDash': 35401,
#  "smartphone's": 35452,
#  "song's": 35454,
#  "Tom's": 35456,
#  "agent's": 35481,
#  "Shapiro's": 35482,
#  "employer's": 35493,
#  'Chinese-Indonesians': 35497,
#  "dosen't": 35533,
#  'PhonePe': 35592,
#  'ি': 35604,
#  "puppy's": 35633,
#  'NIELIT': 35637,
#  "app's": 35657,
#  "Grande's": 35666,
#  'Unocoin': 35667,
#  'RCOEM': 35675,
#  "Maslow's": 35744,
#  'WikiTribune': 35760,
#  "Bieber's": 35765,
#  'ख': 35774,
#  'CA-CPT': 35775,
#  'Ravindrababu': 35810,
#  "Ford's": 35822,
#  'NEET-PG': 35829,
#  "male's": 35853,
#  '<3': 35859,
#  'AlphaGo': 35913,
#  'GraphQL': 35919,
#  'Zoomcar': 36047,
#  'IIHM': 36062,
#  '\\;': 36129,
#  "NRI's": 36178,
#  'भ': 36272,
#  "community's": 36279,
#  "Jon's": 36292,
#  'muoet': 36310,
#  "Brady's": 36313,
#  '1300D': 36318,
#  "question's": 36337,
#  "Hall's": 36339,
#  "Dubai's": 36355,
#  'kmno': 36384,
#  "Patel's": 36417,
#  "generation's": 36478,
#  'IGST': 36491,
#  'RWBY': 36566,
#  "Curry's": 36590,
#  "water's": 36605,
#  "lawyer's": 36608,
#  "Corbyn's": 36621,
#  "Union's": 36621,
#  "NLU's": 36622,
#  "battery's": 36655,
#  "Woman's": 36657,
#  'anti-nationals': 36785,
#  "Jain's": 36830,
#  "CNN's": 36860,
#  "STD's": 36886,
#  'mhcet': 36890,
#  '2π': 36917,
#  'IMUCET': 36932,
#  "White's": 36932,
#  "Today's": 36991,
#  "Hershey's": 36995,
#  "Palpatine's": 37004,
#  'NLUO': 37055,
#  "startup's": 37057,
#  "Turing's": 37085,
#  "Frank's": 37119,
#  "Hamilton's": 37128,
#  'anti-Modi': 37128,
#  'Practo': 37135,
#  '1/3+': 37172,
#  "video's": 37172,
#  "Silva's": 37214,
#  'Ahok': 37286,
#  '-1/12': 37289,
#  'flipcart': 37307,
#  "BTS's": 37339,
#  "Clark's": 37343,
#  'RNSIT': 37353,
#  'Otsutsuki': 37353,
#  'IERT': 37375,
#  'NC-OBC': 37398,
#  "Kelly's": 37402,
#  "Rau's": 37409,
#  'WebAssembly': 37424,
#  "firm's": 37428,
#  "Armstrong's": 37589,
#  '+1/2': 37633,
#  "Wayne's": 37657,
#  'Qyburn': 37710,
#  'ठ': 37734,
#  '2k18': 37739,
#  "pilot's": 37759,
#  "Madrid's": 37793,
#  "associate's": 37817,
#  "plane's": 37830,
#  "dont's": 37861,
#  "Alice's": 37872,
#  'HYPSM': 37920,
#  'Lenskart': 37934,
#  "Android's": 37939,
#  "Rowling's": 37943,
#  'thicc': 37983,
#  "Joseph's": 37990,
#  "Government's": 38058,
#  'BASLP': 38166,
#  "lady's": 38176,
#  'f_': 38209,
#  "Asimov's": 38227,
#  'Kilimall': 38228,
#  'post-truth': 38238,
#  "book's": 38252,
#  'Whydoes': 38309,
#  "Dante's": 38327,
#  "Bangalore's": 38327,
#  "Porter's": 38416,
#  'CPTSD': 38434,
#  "CA's": 38450,
#  "Ender's": 38452,
#  'IIIT-A': 38480,
#  "Twitter's": 38490,
#  'd=': 38493,
#  "fan's": 38520,
#  "Bangladesh's": 38531,
#  "Griffin's": 38538,
#  "Parker's": 38539,
#  'b.pharma': 38581,
#  '1050ti': 38598,
#  "Dany's": 38608,
#  'mmmut': 38689,
#  "day's": 38712,
#  'Tambrahms': 38767,
#  'freebitco.in': 38770,
#  "atheist's": 38801,
#  "leader's": 38837,
#  'incel': 38843,
#  "Homer's": 38845,
#  'IPUCET': 38901,
#  "adult's": 38920,
#  "Kepler's": 38957,
#  "Baratheon's": 38957,
#  "Great's": 38986,
#  "Adam's": 38998,
#  'Umtiti': 39008,
#  'doklam': 39017,
#  'b.pharm': 39018,
#  "Kumaran's": 39051,
#  "Planck's": 39072,
#  "Strange's": 39078,
#  'SPPU': 39085,
#  'crytocurrency': 39149,
#  "ISP's": 39185,
#  "Joker's": 39210,
#  "star's": 39215,
#  'DU-JAT': 39216,
#  "bike's": 39233,
#  'AlphaZero': 39239,
#  "Pelosi's": 39242,
#  "everybody's": 39278,
#  "kitten's": 39317,
#  "reader's": 39339,
#  'cringiest': 39339,
#  'PRMO': 39393,
#  ';}': 39430,
#  'PGDIE': 39458,
#  "law's": 39468,
#  "Doctor's": 39481,
#  "Ashoka's": 39486,
#  'B1B2': 39533,
#  'ँ': 39551,
#  'GDAX': 39573,
#  'darkweb': 39582,
#  "season's": 39582,
#  "Houston's": 39609,
#  "Reagan's": 39659,
#  "Ryan's": 39665,
#  "soldier's": 39668,
#  "Empire's": 39681,
#  "stock's": 39686,
#  'Bolsonaro': 39686,
#  "Metallica's": 39715,
#  'Philando': 39768,
#  "AI's": 39776,
#  "Gambino's": 39778,
#  "Ramsay's": 39834,
#  'XXXTentacion': 39839,
#  'fz25': 39875,
#  "Java's": 39879,
#  "Henry's": 39977,
#  "your's": 39987,
#  'LRDI': 39988,
#  'लन': 40000,
#  "page's": 40018,
#  "Santa's": 40019,
#  'doky.io': 40027,
#  'Midoriya': 40052,
#  'DILR': 40059,
#  "latter's": 40060,
#  "farmer's": 40092,
#  '160r': 40106,
#  "Zapata's": 40113,
#  "cell's": 40150,
#  'ে': 40178,
#  "Tyrion's": 40181,
#  "old's": 40192,
#  'pro-BJP': 40275,
#  "public's": 40276,
#  "Jacob's": 40330,
#  'Waymo': 40357,
#  "Roy's": 40366,
#  "Lawrence's": 40389,
#  "LinkedIn's": 40401,
#  'Trump-Kim': 40414,
#  ...}

# %%
from nltk.stem import PorterStemmer
s=PorterStemmer()
from nltk.stem import LancasterStemmer
l=LancasterStemmer()
from nltk.stem import WordNetLemmatizer
n=WordNetLemmatizer()

glove_oov = {}
i = 0
for word in tqdm(vocab):
    # if i >= max_features: break

    tmp = word
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.lower()
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = word.upper()
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = word.capitalize()
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = s.stem(word)
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue
    
    tmp = l.stem(word)
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = n.lemmatize(word)
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue

    tmp = word.split("'")[0]
    if tmp in glove_embedding:
        # glove_embedding_matrix[i] = glove_embedding[tmp]
        i += 1
        continue





    else:
        glove_oov[word] = i
    
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / len(vocab) * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c12ae8345366> in <module>()
#       8 glove_oov = {}
#       9 i = 0
# ---> 10 for word in tqdm(vocab):
#      11     # if i >= max_features: break
#      12
#
# NameError: name 'tqdm' is not defined

# %%
'scikit-learn' in glove_embedding
# Out:
# True

# %%
'sklearn' in glove_embedding
# Out:
# False

# %%
'Airpods' in glove_embedding
# Out:
# False

# %%
n.lemmatize("Airpods")
# Out:
# 'Airpods'

# %%
s.stem("Airpods")
# Out:
# 'airpod'

# %%
l.stem("Airpods")
# Out:
# 'airpod'

# %%
glove_oov
# Out:
# {'..': 1950,
#  '\u200b': 2002,
#  'cryptocurrencies': 3165,
#  'Brexit': 3189,
#  'Redmi': 3760,
#  'ा': 4110,
#  '₹': 5412,
#  'OnePlus': 8140,
#  'ि': 8483,
#  '(8': 8522,
#  'demonetisation': 9373,
#  'GDPR': 9584,
#  '्': 9662,
#  'BNBR': 9675,
#  'Coinbase': 9708,
#  'े': 9820,
#  'Adityanath': 10324,
#  'Boruto': 10608,
#  'IIEST': 10805,
#  'DCEU': 11061,
#  'alt-right': 11116,
#  'Machedo': 11736,
#  'anti-Trump': 11942,
#  'र': 11955,
#  ')=': 12254,
#  'Qoura': 12535,
#  'LNMIIT': 12540,
#  'न': 12622,
#  'ी': 12671,
#  'Zerodha': 12713,
#  'Upwork': 12837,
#  '}=': 13044,
#  'क': 13088,
#  'Doklam': 13707,
#  '):': 13802,
#  'Unacademy': 13848,
#  'NICMAR': 13899,
#  'Vajiram': 13976,
#  'MUOET': 14247,
#  'ल': 14261,
#  'म': 14368,
#  'Litecoin': 14880,
#  'HackerRank': 15344,
#  "Kavalireddi's": 15429,
#  'altcoin': 15539,
#  'Baahubali': 15571,
#  'Awdhesh': 15685,
#  'eLitmus': 15751,
#  'ो': 15906,
#  'AlShamsi': 15935,
#  'Ryzen': 15958,
#  'altcoins': 16064,
#  'r-aping': 16277,
#  'coinbase': 16318,
#  ':(': 16323,
#  ');': 16545,
#  'MU-OET': 16653,
#  'ं': 16762,
#  'SGSITS': 16872,
#  '_0': 16957,
#  '8:': 16981,
#  '8/': 17190,
#  'Amazon.in': 17197,
#  'SRMJEE': 17311,
#  'त': 17328,
#  'BMSCE': 17493,
#  'ह': 17613,
#  'Skripal': 17788,
#  'litecoin': 17800,
#  'स': 17895,
#  'MHCET': 17906,
#  'BIPC': 17910,
#  '़': 18049,
#  '8)': 18063,
#  'OBC-NCL': 18106,
#  'x²': 18188,
#  'द': 18238,
#  'ु': 18238,
#  '=(': 18338,
#  'Swachh': 18415,
#  'Truecaller': 18651,
#  'Zebpay': 18879,
#  'SRMJEEE': 19031,
#  'Gurugram': 19143,
#  'ै': 19283,
#  'Alshamsi': 19419,
#  'upwork': 19537,
#  '/8': 19669,
#  'TensorFlow': 19713,
#  'clickbait': 19975,
#  'Ravula': 20122,
#  'Chromecast': 20170,
#  'ज': 20280,
#  'य': 20767,
#  '#MeToo': 21057,
#  'Alt-Right': 21117,
#  ':/': 21303,
#  'Bittrex': 21672,
#  'microservices': 21716,
#  'RLWL': 21756,
#  'demonitisation': 21848,
#  'USICT': 21950,
#  'Irodov': 21965,
#  'प': 22084,
#  'Koinex': 22182,
#  'Quora.com': 22219,
#  'B.Des': 22341,
#  'unacademy': 22477,
#  'Zamasu': 22503,
#  '\ufeff': 22835,
#  'Trumpcare': 22850,
#  '#metoo': 22979,
#  'JioFi': 23158,
#  'ग': 23215,
#  'pro-Trump': 23336,
#  'NLUs': 23357,
#  'SSC-CGL': 23396,
#  'Trump-Russia': 23424,
#  'Tensorflow': 23602,
#  'HBTU': 23894,
#  'Codeforces': 23907,
#  'USB-C': 23914,
#  'Patreon': 24092,
#  'VSSUT': 24136,
#  'FTRE': 24142,
#  'Despacito': 24363,
#  'LBSNAA': 24375,
#  'XeF': 24402,
#  'MHTCET': 24430,
#  'brexit': 24460,
#  'undergraduation': 24497,
#  'genderfluid': 24504,
#  "Byju's": 24507,
#  'incels': 24538,
#  'ब': 24574,
#  'JCPOA': 24593,
#  'musical.ly': 24628,
#  'tensorflow': 24634,
#  'IGDTUW': 24684,
#  'Whydo': 24765,
#  'IIT-JAM': 24767,
#  'zebpay': 24861,
#  'Zenfone': 24874,
#  'Arrowverse': 24899,
#  'chapterwise': 24910,
#  'Kalpit': 25064,
#  'HackerEarth': 25116,
#  'EFLU': 25231,
#  '️': 25231,
#  'Xiomi': 25252,
#  'P=': 25562,
#  'PMAY': 25574,
#  "Machedo's": 25741,
#  'AKTU': 25862,
#  'Kubernetes': 25907,
#  'IIITD': 25951,
#  '-1/2': 26077,
#  'OneDrive': 26181,
#  'Kavalireddi': 26392,
#  'D3300': 26555,
#  'Sarahah': 26610,
#  'nanodegree': 26663,
#  'WannaCry': 26750,
#  'Odoo': 26864,
#  'fullform': 26897,
#  'ू': 26994,
#  '2017/2018': 27200,
#  '\\:': 27237,
#  'Kaneki': 27273,
#  'Hotstar': 27517,
#  'करन': 27654,
#  'Kovind': 27661,
#  'twinflame': 27722,
#  '|=': 27732,
#  'Instacart': 27778,
#  'hotstar': 27786,
#  'p=': 27797,
#  'Steemit': 27824,
#  'च': 27971,
#  'DeepMind': 27985,
#  'Mbappe': 28092,
#  'LNCT': 28215,
#  'Theranos': 28239,
#  'zerodha': 28371,
#  'EXTC': 28387,
#  'BS-MS': 28462,
#  '2k17': 28550,
#  'Nanodegree': 28673,
#  'Jungkook': 28677,
#  'Strzok': 28708,
#  '্': 28726,
#  'Cryptocurrencies': 28760,
#  'ra-apist': 28809,
#  'x_': 28836,
#  'React.js': 28847,
#  'ra-aping': 28870,
#  'MH370': 28944,
#  'ftre': 29043,
#  'व': 29174,
#  'koinex': 29197,
#  'Neuralink': 29259,
#  'MMMUT': 29296,
#  'Drumpf': 29453,
#  'Bitfinex': 29508,
#  'SSCBS': 29621,
#  'Awdesh': 29832,
#  'Plancess': 29847,
#  'NEET-UG': 29940,
#  'Kattankulathur': 29976,
#  'Padmaavat': 30023,
#  'Veerwal': 30028,
#  'internshala': 30051,
#  'MSQE': 30065,
#  'VITMEE': 30074,
#  'MH17': 30140,
#  'Dhinchak': 30142,
#  'jiofi': 30552,
#  'AirPods': 30605,
#  'KMnO': 30633,
#  'BMSIT': 30700,
#  'TISSNET': 30813,
#  'USACO': 30904,
#  'demonitization': 31069,
#  'AILET': 31075,
#  'া': 31165,
#  'UPESEAT': 31167,
#  'covfefe': 31229,
#  'Killmonger': 31236,
#  'a_': 31323,
#  'mhtcet': 31349,
#  'crypto-currency': 31523,
#  'srmjee': 31547,
#  'D7200': 31586,
#  'post-Brexit': 31588,
#  'TQWL': 31593,
#  'GSTIN': 31596,
#  'BALLB': 31633,
#  '_1': 31775,
#  '_2': 31775,
#  'Vue.js': 31788,
#  'Kefla': 31837,
#  'Zhihu': 32012,
#  'sarahah': 32101,
#  'PGDBF': 32167,
#  'wumao': 32168,
#  'Kainerugaba': 32249,
#  'Brexiteers': 32368,
#  'Warmbier': 32375,
#  '{8': 32387,
#  'Jupyter': 32436,
#  'ipill': 32499,
#  'Padmavat': 32508,
#  'ड': 32778,
#  '្': 32928,
#  'DSCE': 32992,
#  '\u202a': 33016,
#  'AIMCAT': 33133,
#  'LHMC': 33149,
#  'MobiKwik': 33327,
#  'Feku': 33386,
#  'sayat.me': 33403,
#  'Poloniex': 33406,
#  'Oneplus': 33495,
#  'Taehyung': 33559,
#  'RGIPT': 33576,
#  'DigitalOcean': 33662,
#  'crypto-currencies': 33874,
#  'KGMU': 33924,
#  'Brexiters': 33958,
#  'ट': 34100,
#  'overbrace': 34263,
#  'HomePod': 34536,
#  'Bitconnect': 34552,
#  'IIIT-D': 34641,
#  'JEE-Mains': 34737,
#  'B.des': 34886,
#  'श': 34903,
#  '7700k': 34916,
#  'FZ25': 34920,
#  'MAKAUT': 35177,
#  'MPSTME': 35192,
#  'narcissit': 35586,
#  'GE14': 35746,
#  'DoorDash': 35902,
#  'Chinese-Indonesians': 36004,
#  'PhonePe': 36100,
#  'ি': 36112,
#  'NIELIT': 36146,
#  'Unocoin': 36178,
#  'RCOEM': 36186,
#  'WikiTribune': 36272,
#  'ख': 36287,
#  'CA-CPT': 36288,
#  'Ravindrababu': 36323,
#  'NEET-PG': 36343,
#  '<3': 36374,
#  'AlphaGo': 36428,
#  'GraphQL': 36434,
#  'Zoomcar': 36562,
#  'IIHM': 36577,
#  '\\;': 36644,
#  'भ': 36788,
#  'muoet': 36828,
#  '1300D': 36837,
#  'kmno': 36906,
#  'IGST': 37015,
#  'RWBY': 37090,
#  'anti-nationals': 37317,
#  'mhcet': 37425,
#  '2π': 37452,
#  'IMUCET': 37467,
#  'NLUO': 37594,
#  'anti-Modi': 37671,
#  'Practo': 37678,
#  '1/3+': 37715,
#  'Ahok': 37831,
#  '-1/12': 37834,
#  'flipcart': 37852,
#  'RNSIT': 37900,
#  'Otsutsuki': 37900,
#  'IERT': 37922,
#  'NC-OBC': 37945,
#  'WebAssembly': 37973,
#  '+1/2': 38184,
#  'Qyburn': 38262,
#  'ठ': 38286,
#  '2k18': 38291,
#  'HYPSM': 38478,
#  'Lenskart': 38492,
#  'thicc': 38543,
#  'BASLP': 38728,
#  'f_': 38772,
#  'Kilimall': 38792,
#  'post-truth': 38802,
#  'Whydoes': 38874,
#  'CPTSD': 39002,
#  'IIIT-A': 39050,
#  'd=': 39064,
#  'b.pharma': 39156,
#  '1050ti': 39173,
#  'mmmut': 39265,
#  'Tambrahms': 39344,
#  'freebitco.in': 39347,
#  'incel': 39422,
#  'IPUCET': 39481,
#  'Umtiti': 39593,
#  'doklam': 39602,
#  'b.pharm': 39603,
#  'SPPU': 39673,
#  'crytocurrency': 39737,
#  'DU-JAT': 39807,
#  'AlphaZero': 39831,
#  'cringiest': 39935,
#  'PRMO': 39989,
#  ';}': 40026,
#  'PGDIE': 40054,
#  'B1B2': 40132,
#  'ँ': 40150,
#  'GDAX': 40172,
#  'darkweb': 40181,
#  'Bolsonaro': 40292,
#  'Philando': 40375,
#  'XXXTentacion': 40449,
#  'fz25': 40485,
#  'LRDI': 40601,
#  'लन': 40613,
#  'doky.io': 40642,
#  'Midoriya': 40667,
#  'DILR': 40674,
#  '160r': 40723,
#  'ে': 40797,
#  'pro-BJP': 40896,
#  'Waymo': 40980,
#  'Trump-Kim': 41040,
#  'Kaio-Ken': 41082,
#  'crypto-Jew': 41181,
#  'machedo': 41217,
#  'B.pharm': 41229,
#  'IPU-CET': 41355,
#  'BVCOE': 41428,
#  'YourQuote': 41489,
#  'Bumrah': 41519,
#  'Segwit': 41565,
#  '̺': 41644,
#  'uncollapse': 41659,
#  'Sokovia': 41693,
#  'Dogecoin': 41744,
#  'ध': 41931,
#  'CIWG': 41953,
#  'Novichok': 42116,
#  'SIMSREE': 42145,
#  'zenfone': 42154,
#  'Bajjika': 42165,
#  'ISBF': 42207,
#  'SegWit': 42226,
#  'VESIT': 42268,
#  'ARKit': 42294,
#  'autoencoder': 42428,
#  'Ciaz': 42495,
#  "byju's": 42588,
#  'NIFTEM': 42600,
#  'D5300': 42603,
#  'alt-left': 42729,
#  'Nagerkovil': 42770,
#  'Nearbuy': 42780,
#  'Petuhov': 42991,
#  'Elitmus': 42996,
#  'musigma': 43000,
#  'pre-joining': 43003,
#  'FMGE': 43012,
#  'GFRG': 43084,
#  'GTBIT': 43090,
#  'IIIT-Delhi': 43111,
#  'oswaal': 43113,
#  '1crore': 43123,
#  'Tezos': 43184,
#  'PUBDET': 43256,
#  'Dubsmash': 43303,
#  'NS200': 43420,
#  '-1/3': 43465,
#  '「': 43484,
#  '」': 43484,
#  'OMSCS': 43526,
#  '::': 43602,
#  'Skripals': 43603,
#  'Delloite': 43630,
#  'Randyll': 43635,
#  'LeetCode': 43674,
#  'touchbar': 43699,
#  '1.5-': 43710,
#  '940mx': 43718,
#  'ন': 43789,
#  'sallery': 43790,
#  'LSTMs': 43799,
#  '1/1+': 43825,
#  'r-ape': 43828,
#  'jeemains': 43926,
#  'Daesh': 43993,
#  'Mangalapuram': 44102,
#  'Webnovel': 44163,
#  '้': 44251,
#  'Rejuvalex': 44368,
#  'a²': 44400,
#  'Demonetisation': 44416,
#  'Antminer': 44419,
#  'lnct': 44451,
#  'JECRC': 44467,
#  'Microservices': 44649,
#  'R-CNN': 44655,
#  '1/2+': 44814,
#  'HoloLens': 44867,
#  '7200U': 44890,
#  'PyTorch': 44946,
#  'hyperthymesia': 44951,
#  'blockchain.info': 45017,
#  'boruto': 45022,
#  'wish.com': 45080,
#  'َ': 45127,
#  '͜': 45176,
#  'PGDHRM': 45233,
#  'locopilot': 45252,
#  'घ': 45262,
#  '940MX': 45275,
#  '\xad': 45300,
#  'manspreading': 45443,
#  'कर': 45452,
#  '1080ti': 45505,
#  'ष': 45533,
#  'Quorians': 45562,
#  'srmjeee': 45576,
#  'biromantic': 45608,
#  'IGTV': 45732,
#  'Yiannopolous': 45813,
#  'polyhouse': 45965,
#  'Strowman': 46042,
#  'Mysuru': 46343,
#  'Jung-un': 46350,
#  'Deliveroo': 46359,
#  'toppr': 46371,
#  'MVIT': 46376,
#  'rlwl': 46424,
#  '2018/2019': 46580,
#  '2vec': 46654,
#  'G4560': 46702,
#  'JUIT': 46781,
#  'Oliveboard': 46809,
#  'JGEC': 46849,
#  'Bartetzko': 46957,
#  'aktu': 47049,
#  'NMAMIT': 47143,
#  'Aayog': 47174,
#  'IIITDM': 47184,
#  'cryptocoins': 47196,
#  'छ': 47233,
#  'XVG': 47290,
#  'Izuku': 47298,
#  '2018/19': 47327,
#  'Shifuji': 47333,
#  'do;': 47365,
#  'Kejariwal': 47437,
#  'Caulifla': 47470,
#  'Gurmehar': 47481,
#  'phycopath': 47497,
#  'ব': 47505,
#  'র': 47505,
#  'CUCET': 47523,
#  'ை': 47575,
#  '390 2017': 47642,
#  'న': 47695,
#  'ి': 47695,
#  'Altcoins': 47795,
#  'FRDI': 47851,
#  '6300HQ': 47864,
#  'Bathla': 47887,
#  'empowr': 48026,
#  'cryptocurency': 48150,
#  'cryptocoin': 48263,
#  'थ': 48303,
#  'Bregoli': 48342,
#  '-3/2': 48342,
#  '\u200e': 48375,
#  '. . .': 48388,
#  'ZenFone': 48446,
#  "BYJU'S": 48520,
#  'DataCamp': 48566,
#  'पर': 48569,
#  'BitConnect': 48580,
#  'KGEC': 48609,
#  'RMLNLU': 48620,
#  'MDR-XB': 48645,
#  'PayUMoney': 48669,
#  'whatapp': 48683,
#  'Kasganj': 48691,
#  'orthocentre': 48699,
#  'whatsaap': 48714,
#  'ravindrababu': 48797,
#  'PMKVY': 48819,
#  'Stardew': 48870,
#  '卐': 48890,
#  'Jozwik': 48929,
#  'CarPlay': 48963,
#  'LPUNEST': 48988,
#  '1300d': 49046,
#  '͊': 49116,
#  'ͅ': 49116,
#  "AlShamsi's": 49176,
#  'lbsnaa': 49236,
#  'Mechnovate': 49238,
#  '1/4+': 49289,
#  'Internshala': 49307,
#  'Azdome': 49313,
#  'hyperconjugation': 49332,
#  'CSIR-NET': 49441,
#  'upvoters': 49532,
#  'Bluemix': 49563,
#  'Airpods': 49598,
#  'Wikitribune': 49654,
#  'non-Marathi': 49697,
#  'JEE-Advanced': 49752,
#  'झ': 49761,
#  'Cabba': 49767,
#  'Doscos': 49780,
#  'trignometric': 49816,
#  'adityanath': 49818,
#  '};': 49821,
#  'cryptocurreny': 49836,
#  'cotx': 49858,
#  'cosecx': 49858,
#  '. ..': 49865,
#  'Sharudenko': 49876,
#  'BREXIT': 49931,
#  'IITRAM': 49939,
#  'Snapay': 49964,
#  '-2/3': 49975,
#  'Thadomal': 50001,
#  'madheshis': 50184,
#  'bitconnect': 50194,
#  'Calltend': 50208,
#  'Indominus': 50308,
#  'sapiosexual': 50308,
#  'Oumuamua': 50365,
#  'electrovalent': 50385,
#  'Devasena': 50387,
#  "PlayerUnknown's": 50441,
#  'JN0': 50455,
#  '360/360': 50505,
#  'jungkook': 50691,
#  'balayam': 50697,
#  'Flipcart': 50775,
#  'Altacoin': 50848,
#  "Ravula's": 50880,
#  "Boruto's": 50922,
#  'MAH-CET': 51069,
#  'y53': 51070,
#  'SGTB': 51093,
#  'whtsapp': 51094,
#  'BStat': 51134,
#  'CH-CH': 51154,
#  'Puneri': 51300,
#  'Bijwasan': 51310,
#  'madeeasy': 51312,
#  '3.5-': 51497,
#  'Rautela': 51512,
#  'Tenseigan': 51559,
#  'Codechef': 51648,
#  'kovind': 51680,
#  'UPPCS': 51688,
#  'ई': 51694,
#  'PIBM': 51705,
#  'methanoic': 51719,
#  'Avenatti': 51749,
#  'UpWork': 51889,
#  'mc²': 51905,
#  'Vantablack': 51916,
#  'filecoin': 51932,
#  'bare-chest': 51944,
#  '17B13': 51947,
#  'cryptoassets': 51964,
#  'Mevani': 51981,
#  'Hashflare': 52007,
#  'लग': 52052,
#  'Mewani': 52065,
#  'prilims': 52073,
#  'Divyansh': 52095,
#  'Jiofi': 52110,
#  'Oberlo': 52180,
#  'Baiyue': 52192,
#  'पन': 52316,
#  'Haptik': 52319,
#  'Subnautica': 52324,
#  'duplet': 52353,
#  'Rakshaks': 52386,
#  'প': 52403,
#  'MITID': 52422,
#  'BA.LLB': 52436,
#  'Obergefell': 52440,
#  'BIMARU': 52469,
#  '〖': 52592,
#  '〗': 52592,
#  '2lakhs': 52608,
#  'bittrex': 52632,
#  'Arunabh': 52648,
#  'DEH-P': 52794,
#  'Altcoin': 52903,
#  'Parmanu': 52908,
#  'AIMIM': 52924,
#  'Alt-right': 52935,
#  '2seq': 52985,
#  'dichlorine': 52994,
#  'makaut': 52999,
#  'DUJAT': 53095,
#  'Gateforum': 53103,
#  'Wishfie': 53126,
#  '่': 53247,
#  'suryanamaskar': 53266,
#  'PIVX': 53309,
#  'hbtu': 53386,
#  'फ': 53423,
#  '160R': 53466,
#  'Vistara': 53475,
#  'kgmu': 53501,
#  'NET-JRF': 53503,
#  'delhite': 53576,
#  'AIMCATs': 53704,
#  'TSPSC': 53712,
#  'Nidahas': 53762,
#  'laliga': 53810,
#  '3sin': 54031,
#  'uppcs': 54082,
#  'FNAF': 54088,
#  'Brexiting': 54104,
#  'YYGS': 54132,
#  'Debotosh': 54200,
#  'B.pharmacy': 54225,
#  'Antshares': 54246,
#  'motog': 54250,
#  'Trump-bashing': 54311,
#  'Hapnes': 54339,
#  'UKVI': 54388,
#  '2018-20': 54453,
#  'IMU-CET': 54473,
#  'kingroot': 54483,
#  'diprotic': 54525,
#  'हर': 54557,
#  'IGRUA': 54589,
#  '̭': 54631,
#  '̥': 54631,
#  'Whivh': 54709,
#  'CAR-T': 54723,
#  'testbook': 54772,
#  'GTPL': 54777,
#  'micro-dosing': 54812,
#  'AIACTR': 54812,
#  'upwork.com': 54925,
#  'LMRC': 54927,
#  'golgappa': 54938,
#  'mukt': 54970,
#  'kalpit': 54973,
#  '+1/3': 55019,
#  'Vidyalankar': 55022,
#  'DITISS': 55023,
#  'mastuburation': 55058,
#  'b.des': 55062,
#  'arctg': 55076,
#  'Hardhome': 55121,
#  'U0001f914': 55122,
#  'UiPath': 55156,
#  'non-med': 55202,
#  'ា': 55207,
#  'digilocker': 55233,
#  'Ahch-To': 55236,
#  'CA-IPCC': 55286,
#  'PSIT': 55358,
#  'Hakaishin': 55361,
#  'ు': 55383,
#  'ψ': 55413,
#  'narcassist': 55443,
#  'ex-crush': 55479,
#  'IQOS': 55493,
#  'Almyrantis': 55519,
#  'PGPEM': 55528,
#  'na2so4': 55568,
#  'subjectwise': 55573,
#  'Ghazwa-e-Hind': 55594,
#  'SJMSOM': 55594,
#  '\u202c': 55606,
#  'Qspiders': 55618,
#  'sklearn': 55740,
#  'unexempted': 55757,
#  'elctron': 55764,
#  'ZnCl': 55790,
#  'Garrix': 55797,
#  '18-140': 55798,
#  '13RW': 55884,
#  'namakharam': 55895,
#  'Holdo': 55895,
#  'ryzen': 55895,
#  'ण': 55916,
#  'cofficient': 55916,
#  'IIIT-Hyderabad': 55925,
#  'ranklist': 55934,
#  'nahco': 56053,
#  'ride-hailing': 56066,
#  '8.5+': 56072,
#  'judeo-human': 56072,
#  'civilservice': 56115,
#  'microservice': 56167,
#  'Upwork.com': 56191,
#  '<sub>': 56194,
#  '</sub>': 56194,
#  'cishet': 56224,
#  'Quroa': 56239,
#  'autoencoders': 56255,
#  'mathemathics': 56283,
#  'Yondu': 56383,
#  '2x²': 56384,
#  'pseudo-liberals': 56398,
#  'Ntorq': 56410,
#  'Gazef': 56493,
#  'padmaavat': 56528,
#  'fulform': 56538,
#  'crytocurrencies': 56553,
#  'rajyasabha': 56555,
#  'sickular': 56615,
#  'Ellaria': 56622,
#  'medium.com': 56633,
#  'U0001f602': 56646,
#  'H_': 56653,
#  'oversmart': 56717,
#  'Woxsen': 56741,
#  'non-physicist': 56764,
#  'INSOFE': 56779,
#  'lhmc': 56783,
#  'Zoldyck': 56815,
#  '7200u': 56824,
#  'Tracxn': 56829,
#  'Uraraka': 56902,
#  'Tejashwi': 57001,
#  'Thalaivas': 57028,
#  'LNCTS': 57033,
#  '(=': 57036,
#  '2lakh': 57036,
#  'webnovel': 57139,
#  'awdhesh': 57170,
#  'Mobikwik': 57202,
#  'in2018': 57204,
#  'mastubrate': 57212,
#  'Dimash': 57237,
#  'cocubes': 57451,
#  'na2co3': 57454,
#  'inter-religion': 57481,
#  'blockhain': 57549,
#  'hashgraph': 57676,
#  'block-chain': 57680,
#  "Alshamsi's": 57704,
#  'whattsapp': 57719,
#  'applock': 57786,
#  'whatsap': 57786,
#  'watchOS': 57787,
#  'Juicero': 57954,
#  'OPTCL': 57962,
#  '8values': 57997,
#  'Dwarikesh': 58014,
#  'cscx': 58031,
#  'Whatvis': 58051,
#  '3-4-': 58067,
#  'NoFap': 58080,
#  'Korotkevich': 58088,
#  's-block': 58126,
#  'UberX': 58130,
#  'SIMSR': 58160,
#  'PG-DAC': 58190,
#  '918kiss': 58216,
#  'Tamil-Nadu': 58234,
#  'HashFlare': 58240,
#  'Hampankatta': 58251,
#  'Esdeath': 58303,
#  'niftem': 58313,
#  'dynamodb': 58398,
#  'Momoshiki': 58426,
#  'ौ': 58494,
#  'TSICET': 58530,
#  'MNLU': 58551,
#  'Ryokshin': 58551,
#  'Eroupian': 58610,
#  'stateboard': 58715,
#  'mpharm': 58735,
#  '144hz': 58767,
#  'M.des': 58777,
#  'diffentiate': 58809,
#  'Xapo': 58834,
#  'AvPD': 58868,
#  '1mole': 58876,
#  'D101GGC': 58905,
#  'Blockchain.info': 58931,
#  'reneet': 58982,
#  'IITTM': 59016,
#  'engeeniring': 59035,
#  'Damodardas': 59045,
#  'ன': 59066,
#  'nodemcu': 59073,
#  'hardfork': 59174,
#  'Ossoff': 59207,
#  'D3400': 59208,
#  'AF-P': 59215,
#  '4-4-': 59223,
#  'ΔH': 59291,
#  'redme': 59326,
#  '\x7f': 59347,
#  '2²': 59389,
#  'जल': 59393,
#  'Meghmani': 59394,
#  'padmavat': 59484,
#  'KGMC': 59517,
#  '2017-2019': 59520,
#  'Modi-Shah': 59584,
#  'Gigun': 59609,
#  'Splatoon': 59619,
#  'MVSR': 59620,
#  'demonitised': 59790,
#  'वह': 59791,
#  '991ES': 59791,
#  '991MS': 59791,
#  'musterbation': 59809,
#  'usict': 59816,
#  'Vaporwave': 59873,
#  'iBeacon': 59873,
#  'DSATM': 59962,
#  'y²': 59963,
#  'Ōtsutsuki': 59981,
#  'litecoins': 59994,
#  'Gitlab': 60016,
#  'Odissa': 60096,
#  'iihm': 60103,
#  'HNLU': 60162,
#  'ด': 60194,
#  'Decofest': 60199,
#  'airpods': 60234,
#  'Namjoon': 60283,
#  'Whatbis': 60291,
#  'Na2S2O3': 60293,
#  'nofap': 60442,
#  'Tapzo': 60459,
#  'xcos': 60482,
#  'Howdid': 60490,
#  'Cliven': 60514,
#  '‑': 60519,
#  'onecoin': 60530,
#  ':=': 60596,
#  'Tamoghna': 60623,
#  'CEX.IO': 60627,
#  'subinspector': 60629,
#  'anti-Trumpers': 60648,
#  'Onecoin': 60665,
#  'venturimeter': 60760,
#  'ScoopWhoop': 60848,
#  'UPSC-CSE': 60852,
#  'रन': 60856,
#  'Vajubhai': 60856,
#  'RGNUL': 60861,
#  'IIIT-B': 60880,
#  'Mphill': 60927,
#  'Liberland': 60954,
#  'Katappa': 60954,
#  '-3/4': 60980,
#  'Kahoot': 60997,
#  'speedforce': 61005,
#  '1lac': 61014,
#  'Indoraptor': 61021,
#  'foodpanda': 61048,
#  'Whqt': 61055,
#  'iodometric': 61069,
#  'vistara': 61162,
#  'kasganj': 61180,
#  '10.or': 61222,
#  'RecyclerView': 61224,
#  'JioPhone': 61249,
#  'Toppr': 61270,
#  '6400km': 61305,
#  'Pixelbook': 61305,
#  'jeemain': 61321,
#  'RQWL': 61399,
#  'I_': 61452,
#  'WBCHSE': 61461,
#  'criptocurrency': 61464,
#  'bromoethane': 61464,
#  'க': 61471,
#  'Animoji': 61472,
#  'Covfefe': 61552,
#  '8}': 61560,
#  'IIT-BHU': 61585,
#  'Markiplier': 61588,
#  'Guluzar': 61669,
#  'Tufenk': 61669,
#  "Adityanath's": 61721,
#  'NDEB': 61731,
#  '0.5-': 61779,
#  'API.ai': 61787,
#  'iqoption': 61825,
#  'Xcent': 61846,
#  'IUBH': 61852,
#  'freecharge': 61900,
#  'r-aped': 61901,
#  'Nine-Nine': 61952,
#  'tissnet': 62078,
#  'narccisist': 62139,
#  'BTCI': 62163,
#  'Eastwatch': 62165,
#  'R558UQ': 62173,
#  'आन': 62245,
#  '2017-19': 62271,
#  'gender-fluid': 62309,
#  '̔': 62347,
#  '͒': 62347,
#  '̩': 62347,
#  '̼': 62347,
#  '͎': 62348,
#  '̙': 62348,
#  '̍': 62348,
#  '̟': 62348,
#  '͈': 62349,
#  '̞': 62350,
#  'Belmod': 62354,
#  'pillani': 62366,
#  'AMWF': 62390,
#  'ATH-M': 62397,
#  'GFTI': 62437,
#  'oliveboard': 62450,
#  'Auvela': 62520,
#  'nestaway': 62541,
#  "Ahok's": 62547,
#  'Eobard': 62562,
#  'statergy': 62565,
#  'micro-aggressions': 62576,
#  'moLotus': 62592,
#  'ex-narcissist': 62621,
#  '. .': 62697,
#  'siacoin': 62697,
#  'BVBCET': 62824,
#  'XXXtentacion': 62826,
#  'Accolite': 62839,
#  '్': 62844,
#  'pwBPD': 62896,
#  'Neduvasal': 62922,
#  'Dönmeh': 62947,
#  'sarahah.com': 62955,
#  '135/180': 62970,
#  '44ADA': 62977,
#  'QTUM': 62989,
#  'pseudo-feminists': 62995,
#  '103/200': 63063,
#  'early-entrance-to-college': 63083,
#  'NLIU': 63115,
#  'tybcom': 63124,
#  'α1': 63156,
#  'Rojava': 63170,
#  'Bhallaladeva': 63200,
#  'gangrapes': 63214,
#  'Bytecoin': 63229,
#  'Phinks': 63280,
#  ...}

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
'aBc'.capitalize()
# Out:
# 'Abc'

# %%
from keras.preprocessing.text import Tokenizer

# %%
s = train_df["question_text"].values[312]

# %%
s
# Out:
# 'Why does Israel act as if it is an independent country? Isn’t it a client state of the USA just as it’s predecessor from 2000 years ago was a client Kingdom of the Romans and before that Greeks, before that the Persians and before that Babylonia?'

# %%
tknzr = Tokenizer(lower=False)
tknzr.fit_on_texts([s])

# %%
tknzr.word_index
# Out:
# {'2000': 26,
#  'Babylonia': 34,
#  'Greeks': 32,
#  'Isn’t': 19,
#  'Israel': 12,
#  'Kingdom': 30,
#  'Persians': 33,
#  'Romans': 31,
#  'USA': 21,
#  'Why': 10,
#  'a': 6,
#  'act': 13,
#  'ago': 28,
#  'an': 16,
#  'and': 9,
#  'as': 4,
#  'before': 2,
#  'client': 7,
#  'country': 18,
#  'does': 11,
#  'from': 25,
#  'if': 14,
#  'independent': 17,
#  'is': 15,
#  'it': 5,
#  'it’s': 23,
#  'just': 22,
#  'of': 8,
#  'predecessor': 24,
#  'state': 20,
#  'that': 3,
#  'the': 1,
#  'was': 29,
#  'years': 27}

# %%
nltk.word_tokenize(train_df["question_text"].values[312])
# Out:
# ['Why',
#  'does',
#  'Israel',
#  'act',
#  'as',
#  'if',
#  'it',
#  'is',
#  'an',
#  'independent',
#  'country',
#  '?',
#  'Isn',
#  '’',
#  't',
#  'it',
#  'a',
#  'client',
#  'state',
#  'of',
#  'the',
#  'USA',
#  'just',
#  'as',
#  'it',
#  '’',
#  's',
#  'predecessor',
#  'from',
#  '2000',
#  'years',
#  'ago',
#  'was',
#  'a',
#  'client',
#  'Kingdom',
#  'of',
#  'the',
#  'Romans',
#  'and',
#  'before',
#  'that',
#  'Greeks',
#  ',',
#  'before',
#  'that',
#  'the',
#  'Persians',
#  'and',
#  'before',
#  'that',
#  'Babylonia',
#  '?']

# %%
"'" in glove_embedding
# Out:
# True

# %% [markdown]
# https://www.kaggle.com/bkkaggle/pytorch-determinism-test

# %%
import torchtext
from torchtext.legacy import data

# %% [markdown]
# https://torchtext.readthedocs.io/en/latest/data.html#field
#
# https://wikidocs.net/60314

# %%
q_field = data.Field(tokenize=tweet_tknzr.tokenize, batch_first=True)

# %%
q_field
# Out:
# torchtext.legacy.data.field.Field

# %%
from torchtext.legacy.data import TabularDataset

# %%
question_field = data.Field(tokenize=tweet_tknzr.tokenize, lower=True, batch_first=True, include_lengths=True)
target_field = data.Field(sequential=False, use_vocab=False, batch_first=True)

train_fields = [
    ('id', None),
    ('qid', None),
    ('question_text', question_field),
    ('target', target_field)
]

test_fields = [
    ('qid', None),
    ('question_text', question_field)
]

# %%
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold

# %%
SEED = 31
FOLD = 0
NOTIFY_EACH_EPOCH = False

WORKERS = 0
BATCH_SIZE = 512

N_SPLITS = 10

# %%
kfold = KFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

train_idx, val_idx = list(kfold.split(train_df))[FOLD]
x_train, x_val = train_df.iloc[train_idx], train_df.iloc[val_idx]

x_train.to_csv('train.csv')
x_val.to_csv('val.csv')

# %%
list(kfold.split(train_df))[1]
# Out:
# (array([      0,       1,       2, ..., 1175505, 1175506, 1175508]),
#  array([      6,      26,      34, ..., 1175495, 1175502, 1175507]))

# %%
train, val = TabularDataset.splits(path='./',
                                   train='train.csv',
                                   validation='val.csv',
                                   format='CSV',
                                   fields=train_fields,
                                   skip_header=True
                                   )

# %%
v = question_field.build_vocab(train)

# %%
question_field.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x7fcc8655eb90>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              '?': 2,
#              'the': 3,
#              'what': 4,
#              'is': 5,
#              'a': 6,
#              'to': 7,
#              'in': 8,
#              'of': 9,
#              'i': 10,
#              'how': 11,
#              'and': 12,
#              'do': 13,
#              'are': 14,
#              ',': 15,
#              'for': 16,
#              'you': 17,
#              'can': 18,
#              'why': 19,
#              'it': 20,
#              '.': 21,
#              'my': 22,
#              'that': 23,
#              'if': 24,
#              'with': 25,
#              'or': 26,
#              'on': 27,
#              'have': 28,
#              'be': 29,
#              'does': 30,
#              '"': 31,
#              'from': 32,
#              'your': 33,
#              'an': 34,
#              'which': 35,
#              'should': 36,
#              'when': 37,
#              'get': 38,
#              'best': 39,
#              'would': 40,
#              'as': 41,
#              '(': 42,
#              ')': 43,
#              'people': 44,
#              'some': 45,
#              'there': 46,
#              'who': 47,
#              'will': 48,
#              'like': 49,
#              'not': 50,
#              'at': 51,
#              'about': 52,
#              'they': 53,
#              'by': 54,
#              'was': 55,
#              'did': 56,
#              'we': 57,
#              'any': 58,
#              'so': 59,
#              'good': 60,
#              '/': 61,
#              'me': 62,
#              'their': 63,
#              'one': 64,
#              'has': 65,
#              'india': 66,
#              'after': 67,
#              'most': 68,
#              'where': 69,
#              'this': 70,
#              'make': 71,
#              'but': 72,
#              'more': 73,
#              'all': 74,
#              'think': 75,
#              'many': 76,
#              'between': 77,
#              'than': 78,
#              'time': 79,
#              'much': 80,
#              'other': 81,
#              "'": 82,
#              'life': 83,
#              'someone': 84,
#              'use': 85,
#              'he': 86,
#              '’': 87,
#              'way': 88,
#              'out': 89,
#              'am': 90,
#              'know': 91,
#              'being': 92,
#              'work': 93,
#              'want': 94,
#              'up': 95,
#              'take': 96,
#              'them': 97,
#              'were': 98,
#              'ever': 99,
#              'his': 100,
#              'find': 101,
#              'us': 102,
#              'become': 103,
#              'world': 104,
#              'without': 105,
#              'just': 106,
#              'could': 107,
#              'person': 108,
#              'feel': 109,
#              "don't": 110,
#              'into': 111,
#              'better': 112,
#              'quora': 113,
#              's': 114,
#              'year': 115,
#              'no': 116,
#              'go': 117,
#              'new': 118,
#              'possible': 119,
#              'job': 120,
#              'her': 121,
#              'only': 122,
#              'been': 123,
#              'years': 124,
#              'mean': 125,
#              'indian': 126,
#              "what's": 127,
#              "i'm": 128,
#              'need': 129,
#              'used': 130,
#              'trump': 131,
#              'start': 132,
#              'first': 133,
#              'women': 134,
#              'difference': 135,
#              'money': 136,
#              'had': 137,
#              '2': 138,
#              'still': 139,
#              '-': 140,
#              'different': 141,
#              'really': 142,
#              'while': 143,
#              'school': 144,
#              'learn': 145,
#              'our': 146,
#              'country': 147,
#              'business': 148,
#              'over': 149,
#              'same': 150,
#              'now': 151,
#              'long': 152,
#              'love': 153,
#              'before': 154,
#              'college': 155,
#              'things': 156,
#              'even': 157,
#              'old': 158,
#              'engineering': 159,
#              'give': 160,
#              'during': 161,
#              'she': 162,
#              'help': 163,
#              'online': 164,
#              'its': 165,
#              'say': 166,
#              'day': 167,
#              'see': 168,
#              'bad': 169,
#              'because': 170,
#              '+': 171,
#              'using': 172,
#              'book': 173,
#              '1': 174,
#              'university': 175,
#              'change': 176,
#              'men': 177,
#              'company': 178,
#              'back': 179,
#              'then': 180,
#              'him': 181,
#              'sex': 182,
#              'anyone': 183,
#              'stop': 184,
#              'having': 185,
#              'made': 186,
#              'getting': 187,
#              'high': 188,
#              'girl': 189,
#              'live': 190,
#              'student': 191,
#              'buy': 192,
#              'own': 193,
#              'thing': 194,
#              '2017': 195,
#              'happen': 196,
#              'study': 197,
#              'two': 198,
#              'right': 199,
#              '&': 200,
#              'name': 201,
#              'science': 202,
#              'going': 203,
#              'countries': 204,
#              'something': 205,
#              't': 206,
#              '3': 207,
#              'white': 208,
#              'through': 209,
#              'look': 210,
#              'real': 211,
#              'free': 212,
#              'true': 213,
#              'english': 214,
#              'such': 215,
#              "can't": 216,
#              'come': 217,
#              'china': 218,
#              'experience': 219,
#              'black': 220,
#              'questions': 221,
#              'doing': 222,
#              'number': 223,
#              'against': 224,
#              'american': 225,
#              'class': 226,
#              'water': 227,
#              'important': 228,
#              'students': 229,
#              'system': 230,
#              'very': 231,
#              '2018': 232,
#              'language': 233,
#              'government': 234,
#              'ways': 235,
#              'tell': 236,
#              ':': 237,
#              'state': 238,
#              'computer': 239,
#              'books': 240,
#              'war': 241,
#              'never': 242,
#              'keep': 243,
#              'girls': 244,
#              'man': 245,
#              'always': 246,
#              'off': 247,
#              'every': 248,
#              'social': 249,
#              '5': 250,
#              'friend': 251,
#              'human': 252,
#              'too': 253,
#              '10': 254,
#              'career': 255,
#              'data': 256,
#              'home': 257,
#              'relationship': 258,
#              'place': 259,
#              'software': 260,
#              'chinese': 261,
#              'write': 262,
#              '%': 263,
#              'future': 264,
#              'under': 265,
#              'friends': 266,
#              "doesn't": 267,
#              'done': 268,
#              'exam': 269,
#              'account': 270,
#              'working': 271,
#              'website': 272,
#              'america': 273,
#              'parents': 274,
#              'learning': 275,
#              'app': 276,
#              'food': 277,
#              'x': 278,
#              "it's": 279,
#              'phone': 280,
#              'guy': 281,
#              'family': 282,
#              'around': 283,
#              'believe': 284,
#              'got': 285,
#              'another': 286,
#              'top': 287,
#              'age': 288,
#              'states': 289,
#              'read': 290,
#              'car': 291,
#              'course': 292,
#              'happens': 293,
#              'days': 294,
#              '4': 295,
#              'usa': 296,
#              'kind': 297,
#              'wrong': 298,
#              'big': 299,
#              'google': 300,
#              'also': 301,
#              'each': 302,
#              'power': 303,
#              'companies': 304,
#              'able': 305,
#              'down': 306,
#              'history': 307,
#              'hard': 308,
#              'makes': 309,
#              'movie': 310,
#              'body': 311,
#              'major': 312,
#              'show': 313,
#              'last': 314,
#              'question': 315,
#              'hate': 316,
#              'both': 317,
#              'americans': 318,
#              'canada': 319,
#              'ask': 320,
#              'living': 321,
#              'normal': 322,
#              'less': 323,
#              'degree': 324,
#              'cost': 325,
#              'woman': 326,
#              'test': 327,
#              '^': 328,
#              'considered': 329,
#              'create': 330,
#              'president': 331,
#              'since': 332,
#              'god': 333,
#              'muslims': 334,
#              'pay': 335,
#              'jee': 336,
#              'type': 337,
#              'instead': 338,
#              'well': 339,
#              'great': 340,
#              'facebook': 341,
#              'examples': 342,
#              'child': 343,
#              'common': 344,
#              'actually': 345,
#              'children': 346,
#              'rank': 347,
#              'media': 348,
#              'play': 349,
#              'prepare': 350,
#              'answer': 351,
#              'u': 352,
#              'part': 353,
#              'market': 354,
#              'anything': 355,
#              'united': 356,
#              'process': 357,
#              'eat': 358,
#              'given': 359,
#              'today': 360,
#              'music': 361,
#              'win': 362,
#              'm': 363,
#              'average': 364,
#              'choose': 365,
#              'marks': 366,
#              'end': 367,
#              'house': 368,
#              'call': 369,
#              'tv': 370,
#              'medical': 371,
#              'myself': 372,
#              'next': 373,
#              'law': 374,
#              'earth': 375,
#              'jobs': 376,
#              'writing': 377,
#              'game': 378,
#              'known': 379,
#              'making': 380,
#              'score': 381,
#              'cause': 382,
#              'current': 383,
#              'order': 384,
#              'join': 385,
#              'small': 386,
#              'service': 387,
#              'video': 388,
#              'north': 389,
#              'deal': 390,
#              'reason': 391,
#              'affect': 392,
#              'indians': 393,
#              'apply': 394,
#              'support': 395,
#              'math': 396,
#              'causes': 397,
#              'main': 398,
#              '$': 399,
#              'worth': 400,
#              'these': 401,
#              'bank': 402,
#              'uk': 403,
#              'form': 404,
#              'south': 405,
#              'tips': 406,
#              'etc': 407,
#              'point': 408,
#              'technology': 409,
#              'engineer': 410,
#              'face': 411,
#              'put': 412,
#              'called': 413,
#              'months': 414,
#              'word': 415,
#              'card': 416,
#              'public': 417,
#              'c': 418,
#              'left': 419,
#              'others': 420,
#              'taking': 421,
#              'energy': 422,
#              'those': 423,
#              '”': 424,
#              'marketing': 425,
#              'research': 426,
#              'travel': 427,
#              'meaning': 428,
#              'hair': 429,
#              'improve': 430,
#              'value': 431,
#              'delhi': 432,
#              'lot': 433,
#              'development': 434,
#              '“': 435,
#              'move': 436,
#              'control': 437,
#              'design': 438,
#              'idea': 439,
#              'open': 440,
#              'times': 441,
#              'problem': 442,
#              'program': 443,
#              'light': 444,
#              'management': 445,
#              'found': 446,
#              'pakistan': 447,
#              'iit': 448,
#              'muslim': 449,
#              'away': 450,
#              '=': 451,
#              'safe': 452,
#              'date': 453,
#              'care': 454,
#              'series': 455,
#              'health': 456,
#              'city': 457,
#              'physics': 458,
#              'general': 459,
#              'donald': 460,
#              'education': 461,
#              'air': 462,
#              'political': 463,
#              'enough': 464,
#              'understand': 465,
#              'talk': 466,
#              'single': 467,
#              'international': 468,
#              'level': 469,
#              'android': 470,
#              'required': 471,
#              'weight': 472,
#              'based': 473,
#              'field': 474,
#              'space': 475,
#              'stay': 476,
#              'full': 477,
#              'increase': 478,
#              'mba': 479,
#              'movies': 480,
#              "isn't": 481,
#              'build': 482,
#              'month': 483,
#              'happened': 484,
#              'salary': 485,
#              'group': 486,
#              'problems': 487,
#              'programming': 488,
#              'humans': 489,
#              'available': 490,
#              'everyone': 491,
#              'behind': 492,
#              'popular': 493,
#              'favorite': 494,
#              'legal': 495,
#              'b': 496,
#              'youtube': 497,
#              '6': 498,
#              'said': 499,
#              '12': 500,
#              'often': 501,
#              'death': 502,
#              'low': 503,
#              'benefits': 504,
#              '\\': 505,
#              'military': 506,
#              'again': 507,
#              'e': 508,
#              'mobile': 509,
#              'story': 510,
#              'mind': 511,
#              'boyfriend': 512,
#              'dog': 513,
#              'civil': 514,
#              'society': 515,
#              'female': 516,
#              "didn't": 517,
#              'culture': 518,
#              'successful': 519,
#              'leave': 520,
#              'run': 521,
#              'visa': 522,
#              'kill': 523,
#              'looking': 524,
#              'due': 525,
#              'wear': 526,
#              'girlfriend': 527,
#              'europe': 528,
#              'russia': 529,
#              'religion': 530,
#              'kids': 531,
#              'germany': 532,
#              'purpose': 533,
#              'role': 534,
#              'admission': 535,
#              'internet': 536,
#              'mass': 537,
#              'per': 538,
#              'side': 539,
#              'party': 540,
#              'die': 541,
#              'similar': 542,
#              'colleges': 543,
#              'post': 544,
#              'past': 545,
#              'consider': 546,
#              'guys': 547,
#              'starting': 548,
#              'answers': 549,
#              'information': 550,
#              '{': 551,
#              'web': 552,
#              'skills': 553,
#              'male': 554,
#              'else': 555,
#              'product': 556,
#              'seen': 557,
#              'try': 558,
#              'training': 559,
#              'everything': 560,
#              'mechanical': 561,
#              'speed': 562,
#              'cat': 563,
#              'opinion': 564,
#              'watch': 565,
#              'industry': 566,
#              'few': 567,
#              'force': 568,
#              'studying': 569,
#              'british': 570,
#              'advice': 571,
#              'fight': 572,
#              'gay': 573,
#              'related': 574,
#              'pain': 575,
#              'lose': 576,
#              'yourself': 577,
#              'sell': 578,
#              'modern': 579,
#              '}': 580,
#              'site': 581,
#              'police': 582,
#              'earn': 583,
#              'games': 584,
#              'types': 585,
#              'exist': 586,
#              'share': 587,
#              'area': 588,
#              'night': 589,
#              'though': 590,
#              'effective': 591,
#              'let': 592,
#              'allowed': 593,
#              'application': 594,
#              'themselves': 595,
#              'tax': 596,
#              'interview': 597,
#              'korea': 598,
#              'rate': 599,
#              'blood': 600,
#              'rather': 601,
#              'personal': 602,
#              'term': 603,
#              'machine': 604,
#              'project': 605,
#              'australia': 606,
#              'private': 607,
#              'services': 608,
#              'famous': 609,
#              'case': 610,
#              'effect': 611,
#              'foreign': 612,
#              'bangalore': 613,
#              'paper': 614,
#              'trying': 615,
#              'already': 616,
#              'second': 617,
#              'code': 618,
#              'courses': 619,
#              'difficult': 620,
#              'terms': 621,
#              'period': 622,
#              'set': 623,
#              "i've": 624,
#              'worst': 625,
#              'daily': 626,
#              'compared': 627,
#              'marriage': 628,
#              '[': 629,
#              'easy': 630,
#              'brain': 631,
#              'explain': 632,
#              'mumbai': 633,
#              ']': 634,
#              '100': 635,
#              'amount': 636,
#              'price': 637,
#              'act': 638,
#              'short': 639,
#              'neet': 640,
#              'liberals': 641,
#              'ex': 642,
#              'hours': 643,
#              'universe': 644,
#              'words': 645,
#              'useful': 646,
#              'married': 647,
#              'skin': 648,
#              'plan': 649,
#              'song': 650,
#              'team': 651,
#              'says': 652,
#              'news': 653,
#              'function': 654,
#              'products': 655,
#              'correct': 656,
#              'wants': 657,
#              'towards': 658,
#              'example': 659,
#              'prevent': 660,
#              'treat': 661,
#              'middle': 662,
#              '7': 663,
#              'biggest': 664,
#              'quality': 665,
#              'knowledge': 666,
#              'japanese': 667,
#              'places': 668,
#              'asked': 669,
#              'yet': 670,
#              'follow': 671,
#              'institute': 672,
#              'theory': 673,
#              'rid': 674,
#              'visit': 675,
#              'sleep': 676,
#              'once': 677,
#              'taken': 678,
#              'seem': 679,
#              'happy': 680,
#              'ideas': 681,
#              'mother': 682,
#              'cse': 683,
#              'iphone': 684,
#              'young': 685,
#              'lost': 686,
#              'model': 687,
#              'describe': 688,
#              '20': 689,
#              'turn': 690,
#              'animals': 691,
#              'download': 692,
#              'coaching': 693,
#              'started': 694,
#              'star': 695,
#              'view': 696,
#              'invest': 697,
#              'list': 698,
#              'national': 699,
#              'islam': 700,
#              'offer': 701,
#              'amazon': 702,
#              'three': 703,
#              'may': 704,
#              'red': 705,
#              '12th': 706,
#              'stock': 707,
#              'effects': 708,
#              'wife': 709,
#              'avoid': 710,
#              'oil': 711,
#              'okay': 712,
#              'matter': 713,
#              'vs': 714,
#              'instagram': 715,
#              'sound': 716,
#              'differences': 717,
#              'negative': 718,
#              'fast': 719,
#              'eating': 720,
#              'natural': 721,
#              'week': 722,
#              'develop': 723,
#              'character': 724,
#              'far': 725,
#              'expect': 726,
#              'provide': 727,
#              'chance': 728,
#              'thinking': 729,
#              'exams': 730,
#              "you've": 731,
#              'necessary': 732,
#              'line': 733,
#              'israel': 734,
#              'self': 735,
#              'don': 736,
#              'reasons': 737,
#              'gun': 738,
#              'likely': 739,
#              'japan': 740,
#              'little': 741,
#              'board': 742,
#              'depression': 743,
#              'size': 744,
#              'dream': 745,
#              'jews': 746,
#              'accept': 747,
#              'grow': 748,
#              'professional': 749,
#              'chemical': 750,
#              'modi': 751,
#              'laptop': 752,
#              'chances': 753,
#              'sexual': 754,
#              'security': 755,
#              'remove': 756,
#              'facts': 757,
#              '15': 758,
#              'present': 759,
#              'within': 760,
#              'large': 761,
#              'add': 762,
#              'told': 763,
#              'speak': 764,
#              'together': 765,
#              'send': 766,
#              'must': 767,
#              'apps': 768,
#              'army': 769,
#              'reading': 770,
#              'poor': 771,
#              'option': 772,
#              'feeling': 773,
#              'interesting': 774,
#              'fake': 775,
#              'fall': 776,
#              'becoming': 777,
#              'moving': 778,
#              'financial': 779,
#              '8': 780,
#              '!': 781,
#              'interested': 782,
#              'schools': 783,
#              'head': 784,
#              'prefer': 785,
#              'office': 786,
#              'preparation': 787,
#              'phd': 788,
#              'boy': 789,
#              'investment': 790,
#              'digital': 791,
#              'nothing': 792,
#              'graduate': 793,
#              'father': 794,
#              'least': 795,
#              'cut': 796,
#              'thoughts': 797,
#              'illegal': 798,
#              'subject': 799,
#              'options': 800,
#              'close': 801,
#              'paid': 802,
#              'percentage': 803,
#              'upsc': 804,
#              'european': 805,
#              'impact': 806,
#              'outside': 807,
#              'dating': 808,
#              'western': 809,
#              'income': 810,
#              'here': 811,
#              'husband': 812,
#              'mental': 813,
#              'nuclear': 814,
#              'basic': 815,
#              "aren't": 816,
#              'drive': 817,
#              'studies': 818,
#              'contact': 819,
#              'n': 820,
#              'uses': 821,
#              'languages': 822,
#              'non': 823,
#              'allow': 824,
#              'french': 825,
#              'universities': 826,
#              'break': 827,
#              'java': 828,
#              'might': 829,
#              'chemistry': 830,
#              'personality': 831,
#              'comes': 832,
#              'mains': 833,
#              'higher': 834,
#              'advantages': 835,
#              'land': 836,
#              'population': 837,
#              'characteristics': 838,
#              'racist': 839,
#              'solution': 840,
#              'gate': 841,
#              'store': 842,
#              'physical': 843,
#              'websites': 844,
#              'special': 845,
#              'gain': 846,
#              'teacher': 847,
#              'intelligence': 848,
#              'issues': 849,
#              "you're": 850,
#              'interest': 851,
#              'baby': 852,
#              'check': 853,
#              'russian': 854,
#              'developer': 855,
#              'german': 856,
#              'strong': 857,
#              'email': 858,
#              'obama': 859,
#              'room': 860,
#              'born': 861,
#              'economy': 862,
#              'pressure': 863,
#              'recommend': 864,
#              'changed': 865,
#              'branch': 866,
#              'gets': 867,
#              'marry': 868,
#              'please': 869,
#              'hindi': 870,
#              'fact': 871,
#              'meet': 872,
#              'created': 873,
#              'west': 874,
#              'sites': 875,
#              'rights': 876,
#              'doctor': 877,
#              'rich': 878,
#              'heart': 879,
#              'pursue': 880,
#              'pregnant': 881,
#              'style': 882,
#              'currently': 883,
#              'credit': 884,
#              'startup': 885,
#              'charge': 886,
#              'hand': 887,
#              'positive': 888,
#              'structure': 889,
#              'fat': 890,
#              'solve': 891,
#              'spend': 892,
#              'son': 893,
#              'scope': 894,
#              'd': 895,
#              'dark': 896,
#              'pass': 897,
#              'practice': 898,
#              'bring': 899,
#              'inside': 900,
#              'views': 901,
#              'ms': 902,
#              'early': 903,
#              'africa': 904,
#              'windows': 905,
#              'ok': 906,
#              'hyderabad': 907,
#              'smart': 908,
#              'bitcoin': 909,
#              'building': 910,
#              'partner': 911,
#              'whole': 912,
#              'numbers': 913,
#              'apple': 914,
#              'art': 915,
#              'laws': 916,
#              'videos': 917,
#              'maths': 918,
#              'especially': 919,
#              'network': 920,
#              'among': 921,
#              'christians': 922,
#              'completely': 923,
#              'content': 924,
#              'talking': 925,
#              'healthy': 926,
#              'source': 927,
#              'crush': 928,
#              'film': 929,
#              'cold': 930,
#              'save': 931,
#              'iq': 932,
#              'topics': 933,
#              'officer': 934,
#              'stupid': 935,
#              '…': 936,
#              'cbse': 937,
#              'works': 938,
#              'alone': 939,
#              'mom': 940,
#              'near': 941,
#              'certain': 942,
#              'complete': 943,
#              'text': 944,
#              'according': 945,
#              'ca': 946,
#              'factors': 947,
#              'treatment': 948,
#              'ones': 949,
#              'fear': 950,
#              'pune': 951,
#              'dogs': 952,
#              'simple': 953,
#              '50': 954,
#              '30': 955,
#              'cell': 956,
#              'needed': 957,
#              'gas': 958,
#              'global': 959,
#              'opportunities': 960,
#              'songs': 961,
#              'eyes': 962,
#              'hurt': 963,
#              'written': 964,
#              'reduce': 965,
#              'yes': 966,
#              'giving': 967,
#              'ago': 968,
#              'minimum': 969,
#              'coming': 970,
#              'religious': 971,
#              'electrical': 972,
#              'train': 973,
#              'asian': 974,
#              'distance': 975,
#              'dead': 976,
#              'democrats': 977,
#              'buying': 978,
#              'attack': 979,
#              'insurance': 980,
#              'letter': 981,
#              'teach': 982,
#              'exactly': 983,
#              'file': 984,
#              'novel': 985,
#              'multiple': 986,
#              '11': 987,
#              'color': 988,
#              'community': 989,
#              'christian': 990,
#              'advanced': 991,
#              'playing': 992,
#              'race': 993,
#              'method': 994,
#              'east': 995,
#              'policy': 996,
#              'mathematics': 997,
#              'fix': 998,
#              'abroad': 999,
#              ...})

# %%
vectors = torchtext.vocab.Vectors('../input/embeddings/glove.840B.300d/glove.840B.300d.txt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-84-5c667237bdef> in <module>()
# ----> 1 vectors = torchtext.vocab.Vectors('../input/embeddings/glove.840B.300d/glove.840B.300d.txt')
#
# /usr/local/lib/python3.7/dist-packages/torchtext/vocab.py in __init__(self, name, cache, url, unk_init, max_vectors)
#     324         self.dim = None
#     325         self.unk_init = torch.Tensor.zero_ if unk_init is None else unk_init
# --> 326         self.cache(name, cache, url=url, max_vectors=max_vectors)
#     327
#     328     def __getitem__(self, token):
#
# /usr/local/lib/python3.7/dist-packages/torchtext/vocab.py in cache(self, name, cache, url, max_vectors)
#     373                             tar.extractall(path=cache)
#     374             if not os.path.isfile(path):
# --> 375                 raise RuntimeError('no vectors found at {}'.format(path))
#     376
#     377             logger.info("Loading vectors from {}".format(path))
#
# RuntimeError: no vectors found at .vector_cache/../input/embeddings/glove.840B.300d/glove.840B.300d.txt

# %%
question_field.vocab.set_vectors(vectors.stoi, vectors.vectors, vectors.dim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-6d3816bc3400> in <module>()
# ----> 1 question_field.vocab.set_vectors(vectors.stoi, vectors.vectors, vectors.dim)
#
# NameError: name 'vectors' is not defined

# %% [markdown]
# references:
#
# https://www.kaggle.com/strideradu/word2vec-and-gensim-go-go-go
#
# https://www.kaggle.com/alhalimi/tokenization-and-word-embedding-compatibility
#
# https://www.kaggle.com/canming/ensemble-mean-iii-64-36

# %%
import nltk
from nltk.tokenize import TweetTokenizer, word_tokenize

# %%
s =  "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <--"

# %%
# nltk.download('punkt')
word_tokenize(s)
# Out:
# ['This',
#  'is',
#  'a',
#  'cooool',
#  '#',
#  'dummysmiley',
#  ':',
#  ':',
#  '-',
#  ')',
#  ':',
#  '-P',
#  '<',
#  '3',
#  'and',
#  'some',
#  'arrows',
#  '<',
#  '>',
#  '-',
#  '>',
#  '<',
#  '--']

# %%
t = TweetTokenizer(reduce_len=True)

# %%
s1 = 'heyyyy nice to meet you!!'

# %%
t.tokenize(s1)
# Out:
# ['heyyy', 'nice', 'to', 'meet', 'you', '!', '!']

# %%
import gc

import numpy as np
import pandas as pd
from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
import os

# input_path = '/kaggle/input/quora-insincere-questions-classification'
input_path = '/content/drive/MyDrive/ColabNotebooks/QIQC/data'
train_path = os.path.join(input_path, 'train.csv')
test_path = os.path.join(input_path, 'test.csv')
embeddings_path = os.path.join(input_path, 'embeddings.zip')

# %%
if os.path.exists(train_path): train_df = pd.read_csv(train_path)
else: train_df = pd.read_csv(train_path + '.zip')

if os.path.exists(test_path): test_df = pd.read_csv(train_path)
else: test_df = pd.read_csv(test_path + '.zip')

print('train shape:', train_df.shape)
print('test shape:', test_df.shape)
# Out:
# train shape: (1306122, 3)
# test shape: (1306122, 3)

# %%
from sklearn.model_selection import train_test_split

# split to train and val
train_df, val_df = train_test_split(train_df, test_size=0.1)

# some config values 
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use

# fill up the missing values
train_X = train_df["question_text"].fillna("_na_").values
val_X = val_df["question_text"].fillna("_na_").values
test_X = test_df["question_text"].fillna("_na_").values

# Get the target values
train_y = train_df['target'].values
val_y = val_df['target'].values

# %%
# %%time
from keras.preprocessing.text import Tokenizer

# Tokenize the sentences
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(train_X))
train_X = tokenizer.texts_to_sequences(train_X)
val_X = tokenizer.texts_to_sequences(val_X)
test_X = tokenizer.texts_to_sequences(test_X)
# Out:
# CPU times: user 50.2 s, sys: 508 ms, total: 50.7 s
# Wall time: 50.6 s

# %%
# %%time
from keras.preprocessing.sequence import pad_sequences

# Pad the sentences 
train_X = pad_sequences(train_X, maxlen=maxlen)
val_X = pad_sequences(val_X, maxlen=maxlen)
test_X = pad_sequences(test_X, maxlen=maxlen)
# Out:
# CPU times: user 10.3 s, sys: 304 ms, total: 10.6 s
# Wall time: 10.4 s

# %%
import zipfile
from gensim.models import KeyedVectors

glove = 'glove.840B.300d/glove.840B.300d.txt'
wiki = 'wiki-news-300d-1M/wiki-news-300d-1M.vec'
google = 'GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'
para = 'paragram_300_sl999/paragram_300_sl999.txt'


def load_embedding(embedding_name):

    def get_coefs(word, *arr): return word, np.asarray(arr, dtype='float32')

    with zipfile.ZipFile(embeddings_path) as embeddings_zip:
        print("Found embeddings as a zip file")

        if embedding_name == google:
            return KeyedVectors.load_word2vec_format(embeddings_zip.open(google), binary=True)

        else:
            embedding = []
            for o in embeddings_zip.open(embedding_name):
                try:
                    if len(o.decode('utf-8')) > 100:
                        embedding.append(get_coefs(*o.decode('utf-8').split(" ")))
                except:
                    pass
        
        return dict(embedding)

# %%
# %%time
glove_embedding = load_embedding(glove) # 3min 21s in Colab
# Out:
# Found embeddings as a zip file
# CPU times: user 3min 13s, sys: 3.82 s, total: 3min 17s
# Wall time: 3min 18s

# %%
# %%time
wiki_embedding = load_embedding(wiki) # 1min 20s in Colab
# Out:
# Found embeddings as a zip file
# CPU times: user 1min 19s, sys: 2.1 s, total: 1min 21s
# Wall time: 1min 21s

# %%
# %%time
google_embedding = load_embedding(google) # 1min 50s in Colab
# Out:
# Found embeddings as a zip file
# CPU times: user 1min 46s, sys: 3.65 s, total: 1min 50s
# Wall time: 1min 50s

# %%
# %%time
para_embedding = load_embedding(para) # 2min 40s in Colab
# Out:
# Found embeddings as a zip file
# CPU times: user 2min 34s, sys: 2.81 s, total: 2min 36s
# Wall time: 2min 36s

# %%
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))

# %%
has_get_emb_stats = True # set False if we have not get emb stats
if not has_get_emb_stats:

    def get_emb_stats(embedding):

        # Put all embeddings in a numpy matrix
        try:
            all_embs= np.stack(embedding.values())
        except:
            all_embs = embedding.vectors

        # Get embedding stats
        emb_mean = all_embs.mean()
        emb_std = all_embs.std()
        
        return emb_mean,emb_std
    

    glove_emb_mean, glove_emb_std = get_emb_stats(glove_embedding)
    wiki_emb_mean, wiki_emb_std = get_emb_stats(wiki_embedding)
    google_emb_mean, google_emb_std = get_emb_stats(google_embedding)
    para_emb_mean, para_emb_std = get_emb_stats(para_embedding)

    print('glove emb mean:', glove_emb_mean, 'emb_std:', glove_emb_std)
    print('wiki emb mean:', wiki_emb_mean, 'emb_std:', wiki_emb_std)
    print('google emb mean:', google_emb_mean, 'emb_std:', google_emb_std)
    print('para emb mean:', para_emb_mean, 'emb_std:', para_emb_std)

else:
    glove_emb_mean, glove_emb_std = -0.005838499, 0.48782197
    wiki_emb_mean, wiki_emb_std = -0.0033469985, 0.109855495
    google_emb_mean, google_emb_std = -0.003527845, 0.13315111
    para_emb_mean, para_emb_std = -0.0053248387, 0.49346521

# %%
glove_embedding_matrix = np.random.normal(glove_emb_mean, glove_emb_std, (max_features, embed_size))
wiki_embedding_matrix = np.random.normal(wiki_emb_mean, wiki_emb_std, (max_features, embed_size))
google_embedding_matrix = np.random.normal(google_emb_mean, google_emb_std, (max_features, embed_size))
para_embedding_matrix = np.random.normal(para_emb_mean, para_emb_std, (max_features, embed_size))

# %%
glove_oov = {}
wiki_oov = {}
google_oov = {}
para_oov = {}
for word, i in tqdm(word_index.items()):
    if i >= max_features: continue
    if word in glove_embedding:
        embedding_vector = glove_embedding[word]
        glove_embedding_matrix[i] = embedding_vector
    else:
        glove_oov[word] = i
    if word in wiki_embedding:
        embedding_vector = wiki_embedding[word]
        wiki_embedding_matrix[i] = embedding_vector
    else:
        wiki_oov[word] = i
    if word in google_embedding:
        embedding_vector = google_embedding[word]
        google_embedding_matrix[i] = embedding_vector
    else:
        google_oov[word] = i
    if word in para_embedding:
        embedding_vector = para_embedding[word]
        para_embedding_matrix[i] = embedding_vector
    else:
        para_oov[word] = i
# Out:
# HBox(children=(FloatProgress(value=0.0, max=209512.0), HTML(value='')))

# %%
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))
print('percentage of oov of wiki: {:.2f}%'.format(len(wiki_oov) / max_features * 100))
print('percentage of oov of google: {:.2f}%'.format(len(google_oov) / max_features * 100))
print('percentage of oov of para: {:.2f}%'.format(len(para_oov) / max_features * 100))
# Out:
# percentage of oov of glove: 8.02%
# percentage of oov of wiki: 14.56%
# percentage of oov of google: 23.63%
# percentage of oov of para: 5.55%

# %% [markdown]
# We will clean the numbers.

# %%
import re

def clean_numbers(x):

    x = re.sub('[0-9]{5,}', '#####', x)
    x = re.sub('[0-9]{4}', '####', x)
    x = re.sub('[0-9]{3}', '###', x)
    x = re.sub('[0-9]{2}', '##', x)
    
    return x

# %%
no_num_tokenizer = Tokenizer()
no_num_tokenizer.fit_on_texts(list(train_df['question_text'].fillna('__na__').progress_apply(lambda x: clean_numbers(x)).values))

# %%
import random

for i in range(10):
    n = random.randint(0, 20000)
    if str(n) not in glove_embedding: print(n, 'is not in glove embedding')
    if str(n) not in wiki_embedding: print(n, 'is not in wiki embedding')
    # if str(n) not in google_embedding: print(n, 'is not in google embedding')
    if str(n) not in para_embedding: print(n, 'is not in para embedding')

# %% [markdown]
# google embedding only have few numbers so we will clean all the numbers.
#
# It seems like other embeddings have numbers up to 10,000 so we will not clean the numbers.

# %%
no_num_word_index = no_num_tokenizer.word_index

google_oov = {}
for word, i in tqdm(no_num_word_index.items()):
    if i >= max_features: continue
    if word in google_embedding:
        embedding_vector = google_embedding[word]
        google_embedding_matrix[i] = embedding_vector
    else:
        google_oov[word] = i

# %%
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))
print('percentage of oov of wiki: {:.2f}%'.format(len(wiki_oov) / max_features * 100))
print('percentage of oov of google: {:.2f}%'.format(len(google_oov) / max_features * 100))
print('percentage of oov of para: {:.2f}%'.format(len(para_oov) / max_features * 100))

# %% [markdown]
# percentage of oov of google: 22.63% -> 22.13%
#
# Some trials to make better performance..

# %%
"don't" in google_embedding

# %%
google_oov

# %%
"i'm" in glove_oov

# %%
glove_oov

# %%
"you’re" in glove_embedding

# %%
for punct in '?!.,"#$%\'()*+-/:;<=>@[\\]^_`{|}~' + '“”’':
    if punct not in glove_embedding:
        print(punct)

# Although “”’are in glove_embedding but we will replace it for convinience

# %%
word = "someone’s"
word = word.replace("’", "'")
if word.endswith("'s") or word.endswith("' s"):
    w1, w2 = word.split("'")
print(w1)
print(w2)

# %%
glove_oov = {}
for word, i in tqdm(word_index.items()):
    if i >= max_features: continue

    if word in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[word]
        continue

    word = word.replace("’", "'")
    word = word.replace('”', '"')
    word = word.replace('“', '"')
    if word in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[word]
        continue
    
    word = re.sub(' +', '', word)
    if word in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[word]
        continue

    tmp_word = word.split("'")[0]
    if tmp_word in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[tmp_word]
        continue
    
    for punct in '?!.,"#$%\'()*+-/:;<=>@[\\]^_`{|}~':
        word = word.replace(punct, '')
    if word in glove_embedding:
        glove_embedding_matrix[i] = glove_embedding[word]
        continue
    
    # quorans -> quora contributors
    

    else:
        glove_oov[word] = i

# %%
print('percentage of oov of glove: {:.2f}%'.format(len(glove_oov) / max_features * 100))

# %% [markdown]
# 8.15% -> 4.18%

# %%
'Quora' in glove_embedding

# %%
for k in word_index.keys():
    if word_index[k] == 49990:
        print(k)

# %%
word_index["'call"]

# %%
''

# %%
glove_oov
